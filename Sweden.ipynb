# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:
    
    # Define the two lists to concatenate
    DataScience = ['Data Science', 'Big data', 'Machine learning','ML', 'Data mining', 'Artificial intelligence', 'AI', 'Predictive modeling',
               'Statistical analysis', 'Data visualization', 'Deep learning', 'Natural language processing', 'Business intelligence',
               'Data warehousing', 'Data management', 'Data cleaning', 'Feature engineering', 'Time series analysis', 'Text analytics',
               'Database', 'SQL', 'NoSQL', 'Neural networks', 'Regression analysis', 'Clustering', 'Dimensionality reduction',
               'Anomaly detection', 'Recommender systems', 'Data integration', 'Data governance']
    
    MachineLearning = ['Machine learning', 'Data preprocessing', 'Feature selection', 'Feature engineering', 'Data visualization',
                   'Model selection', 'Hyperparameter tuning', 'Cross-validation', 'Ensemble methods', 'Neural networks', 'Deep learning',
                   'Convolutional neural networks', 'Recurrent neural networks', 'Natural language processing', 'Computer vision',
                   'Reinforcement learning', 'Unsupervised learning', 'Clustering', 'Dimensionality reduction', 'Bayesian methods',
                   'Time series analysis', 'Random forest', 'Gradient boosting', 'Support vector machines', 'Decision trees', 'Regression analysis']

    # Concatenate the two lists
    keywords = DataScience + MachineLearning
    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %% [markdown]
# ## Scrappigng data for Sweden

# %%
country_name= "Sweden"
geoId="105117694"
companies=['Klarna', 'Spotify', ' Scania', 'Ericsson', 'Volvo Group', 'Electrolux', 'H&M', 'Nordea', 'Handelsbanken', 'Swedbank', 'SAS', 'Atlas Copco', 'Com Hem', 'Net Insight', 'Tacton', 'Peltarion', 'Fidesmo', 'Sup46', 'Kognity', 'Karma', 'Mavenoid', 'Qualcomm', 'Northvolt', 'King', 'TDA Creative', 'Ark Kapital', 'Sinch', 'AFRY', 'TELUS International AI Data Solutions', 'Chalmers University of Technology', 'Linköping University', 'Arm', 'Frontiers', 'AstraZeneca', 'Amoria Bond', 'CGI', 'TELUS International']

print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("DS_jobs_sweden.json")
# Out:
# Country:  Sweden
#
# Company 1: Klarna
#          Job 1: Product Manager - Platform Products downloaded!
#          Job 2: Sanctions & AML Governance downloaded!
#          Job 3: Director, Global Vendor Operations downloaded!
#          Job 4: Senior Product Manager - Platform Products downloaded!
#          Job 5: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 6: Senior Software Engineer - Functional Programming downloaded!
#          Job 7: Sanctions & AML Governance downloaded!
#          Job 8: Senior Product Manager - Platform Products downloaded!
#          Job 9: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 10: Senior Software Engineer - Java downloaded!
#          Job 11: Frontend Developer / Sweden downloaded!
# Company 2: Spotify
#          Job 1: Digital Operations Specialist downloaded!
#          Job 2: Digital Operations Specialist downloaded!
#          Job 3: Python Software Developer downloaded!
#          Job 4: C++ Software Developer downloaded!
#          Job 5: Associate Data Analyst downloaded!
#          Job 6: CRM Specialist downloaded!
#          Job 7: Data Engineer downloaded!
#          Job 8: Product Designer downloaded!
#          Job 9: Data Engineer downloaded!
#          Job 10: C++ Software Developer downloaded!
#          Job 11: Associate Data Analyst downloaded!
#          Job 12: Junior Backend Engineer downloaded!
#          Job 13: Python Software Developer downloaded!
#          Job 14: Associate Data Analyst downloaded!
#          Job 15: Python Software Developer downloaded!
#          Job 16: Data Engineer downloaded!
#          Job 17: Financial & Business Controller downloaded!
#          Job 18: Frontend Engineer downloaded!
# Company 3: Scania
#          No jobs found for Scania
# Company 4: Ericsson
#          Job 1: Developer - Common Information Layer downloaded!
#          Job 2: Python Software Developer downloaded!
#          Job 3: C++ Software Developer downloaded!
#          Job 4: Integration Engineer downloaded!
#          Job 5: Integration Engineer downloaded!
#          Job 6: Developer - Common Information Layer downloaded!
#          Job 7: Python Software Developer downloaded!
#          Job 8: C++ Software Developer downloaded!
#          Job 9: Integration Engineer downloaded!
#          Job 10: Integration Engineer downloaded!
#          Job 11: Developer - Common Information Layer downloaded!
#          Job 12: Integration Engineer downloaded!
#          Job 13: Python Software Developer downloaded!
#          Job 14: Integration Engineer downloaded!
#          Job 15: Integration Engineer downloaded!
#          Job 16: Developer - Common Information Layer downloaded!
#          Job 17: Python Software Developer downloaded!
#          Job 18: Integration Engineer downloaded!
#          Job 19: Integration Engineer downloaded!
#          Job 20: Python Software Developer downloaded!
#          Job 21: C++ Software Developer downloaded!
#          Job 22: Integration Engineer downloaded!
#          Job 23: Integration Engineer downloaded!
#          Job 24: Developer - Common Information Layer downloaded!
#          Job 25: Integration Engineer downloaded!
#          Job 26: Integration Engineer downloaded!
#          Job 27: Python Software Developer downloaded!
#          Job 28: C++ Software Developer downloaded!
# Company 5: Volvo Group
#          No jobs found for Volvo Group
# Company 6: ABB
#          No jobs found for ABB
# Company 7: Autoliv
#          Job 1: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 2: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 3: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 4: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 5: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 6: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 7: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 8: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 9: Requirement Management & Systems Engineering Business Leader downloaded!
#          Job 10: Requirement Management & Systems Engineering Business Leader downloaded!
# Company 8: Electrolux
#          Job 1: Data Engineer downloaded!
#          Job 2: .NET developers downloaded!
#          Job 3: Product Service Specialist, Europe downloaded!
#          Job 4: Data Engineer downloaded!
# Company 9: H&M
#          No jobs found for H&M
# Company 10: Telia Company
#          No jobs found for Telia Company
# Company 11: SEB
#          No jobs found for SEB
# Company 12: Nordea
#          Job 1: Complex Intelligence Analyst downloaded!
#          Job 2: Senior IT Analyst downloaded!
# Company 13: Handelsbanken
#          Job 1: Learning & Development specialist, (LMS) Handelsbanken downloaded!
# Company 14: Swedbank
#          No jobs found for Swedbank
# Company 15: SAS
#          Job 1: IT BUSINESS ANALYST downloaded!
#          Job 2: Information Technology Business Analyst downloaded!
#          Job 3: DATA ANALYST downloaded!
#          Job 4: Data Scientist/Data Engineer downloaded!
#          Job 5: Nationalekonom med statistikkunskaper till SCB downloaded!
#          Job 6: Data Warehouse-utvecklare/arkitekt till Swedbank downloaded!
#          Job 7: IT BUSINESS ANALYST downloaded!
#          Job 8: DATA ANALYST downloaded!
#          Job 9: Riskanalytiker downloaded!
#          Job 10: Nationalekonom med statistikkunskaper till SCB downloaded!
#          Job 11: IT BUSINESS ANALYST downloaded!
# Company 16: Saab
#          No jobs found for Saab
# Company 17: Boliden
#          No jobs found for Boliden
# Company 18: Atlas Copco
#          Job 1: Utvecklare inom inbyggda system till Atlas Copco downloaded!
#          Job 2: Tech Communicator to Atlas Copco downloaded!
#          Job 3: Backendutvecklare till Atlas Copco downloaded!
#          Job 4: Utvecklare inom inbyggda system till Atlas Copco downloaded!
#          Job 5: Backendutvecklare till Atlas Copco downloaded!
# Company 19: SKF
#          No jobs found for SKF
# Company 20: Alfa Laval
#          No jobs found for Alfa Laval
# Company 21: Tele2
#          No jobs found for Tele2
# Company 22: Com Hem
#          No jobs found for Com Hem
# Company 23: Net Insight
#          No jobs found for Net Insight
# Company 24: Tacton
#          Job 1: Marketing Operations & Analytics Manager downloaded!
# Company 25: Peltarion
#          No jobs found for Peltarion
# Company 26: Fidesmo
#          No jobs found for Fidesmo
# Company 27: Sup46
#          No jobs found for Sup46
# Company 28: Kognity
#          No jobs found for Kognity
# Company 29: Karma
#          No jobs found for Karma
# Company 30: Mavenoid
#          No jobs found for Mavenoid
# Company 31: Qualcomm
#          Job 1: Software Engineer- Qualcomm, Linkoping, Sweden downloaded!
#          Job 2: Software Engineer - Qualcomm, Linkoping, Sweden downloaded!
#          Job 3: Systems Engineer predev - Qualcomm, Linköping, Sweden downloaded!
#          Job 4: Senior Software Engineer within Automotive Tech - Qualcomm, Linkoping, Sweden downloaded!
#          Job 5: Job Posting Title Senior Software Engineer within Automotive Tech - Qualcomm, Linköping, Sweden downloaded!
#          Job 6: Senior Software Engineer within Automotive Tech - Qualcomm, Linköping, Sweden downloaded!
#          Job 7: Junior Mjukvaruutvecklare till Qualcomm downloaded!
# Company 32: Northvolt
#          Job 1: Prototype Lab Manager downloaded!
#          Job 2: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 3: Prototype Lab Manager downloaded!
#          Job 4: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 5: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 6: Battery Analyst - R&D downloaded!
#          Job 7: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 8: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 9: Prototype Lab Manager downloaded!
#          Job 10: Battery Analyst - R&D downloaded!
# Company 33: King
#          No jobs found for King
# Company 34: TDA Creative
#          Job 1: Data Engineer Trade AI Team downloaded!
# Company 35: Ark Kapital
#          No jobs found for Ark Kapital
# Company 36: Sinch
#          No jobs found for Sinch
# Company 37: AFRY
#          No jobs found for AFRY
# Company 38: TELUS International AI Data Solutions
#          No jobs found for TELUS International AI Data Solutions
# Company 39: Chalmers University of Technology
#          No jobs found for Chalmers University of Technology
# Company 40: Linköping University
#          Job 1: Doktorand inom design downloaded!
# Company 41: Arm
#          Job 1: Senior Software Engineer, High-Performance Embedded Software (SE) downloaded!
#          Job 2: Dynamic Documentation Lead (SE) downloaded!
#          Job 3: Cloud Frontend Engineer (SE) downloaded!
# Company 42: Frontiers
#          No jobs found for Frontiers
# Company 43: AstraZeneca
#          Job 1: Head of Respiratory & Immunology, Neuroscience, Vaccines & Immune Therapies (RINVI) Safety downloaded!
#          Job 2: Director Product Management (Data Science and AI) downloaded!
# Company 44: Amoria Bond
#          No jobs found for Amoria Bond
# Company 45: CGI
#          Job 1: Data Engineer downloaded!
# Company 46: TELUS International
#          Job 1: Online Data Analyst downloaded!
#          Job 2: Online Data Analyst downloaded!
#          Job 3: Online Data Analyst downloaded!
#          Job 4: Online Data Analyst downloaded!
#          Job 5: Online Data Analyst downloaded!
#          Job 6: Online Data Analyst downloaded!
#          Job 7: Online Data Analyst downloaded!
#          Job 8: Online Data Analyst downloaded!
#          Job 9: Online Data Analyst downloaded!
#          Job 10: Online Data Analyst downloaded!
#          Job 11: Online Data Analyst downloaded!
#          Job 12: Online Data Analyst downloaded!
#          Job 13: Online Data Analyst downloaded!
#          Job 14: Online Data Analyst downloaded!
#          Job 15: Online Data Analyst downloaded!
#          Job 16: Personalized Internet Ads Assessor - Sweden downloaded!
#          Job 17: Online Data Analyst downloaded!
#          Job 18: Online Data Analyst downloaded!
#          Job 19: Online Data Analyst downloaded!
#          Job 20: Online Data Analyst downloaded!
#          Job 21: Online Data Analyst downloaded!
#          Job 22: Online Data Analyst downloaded!
#          Job 23: Online Data Analyst downloaded!
#
# Total 139 jobs downloaded!

# %% [markdown]
# # full stalk Sweden

# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:    

    # Concatenate the two lists
    keywords = ['Front-end development', 'HTML', 'CSS', 'JavaScript', 'React', 'Angular', 'Vue.js', 'Bootstrap', 'jQuery', 'responsive design',      'Back-end development', 'Node.js', 'Python', 'Ruby', 'PHP', 'Java', '.NET', 'SQL', 'NoSQL', 'RESTful APIs', 'web servers',      'Database management', 'MySQL', 'PostgreSQL', 'MongoDB', 'Redis', 'Cassandra', 'Oracle', 'SQL Server',      'DevOps', 'AWS', 'Azure', 'Google Cloud', 'Docker', 'Kubernetes', 'Git', 'Jenkins', 'Travis CI', 'CircleCI', 'monitoring and logging tools',      'Project management', 'Agile', 'Scrum', 'Kanban', 'JIRA', 'Trello', 'Asana', 'project planning', 'team collaboration', 'communication skills']

    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %%
country_name= "Sweden"
geoId="105117694"
companies = ['SimpleSign', 'InterEx Group', 'Iver Sverige', 'HCLTech', 'Fortnox', 'Orbis', 'Lynk & Co', 'Swedbank','Computer Futures', 'HiQ', 'Canonical', 'Nexer Group','Enfo', 'tretton37', 'Tietoevry', 'Fortnox', 'HiQ', 'Boeing', 'Bluestep Bank', 'Telavox', 'Klarna', 'Scania', 'Volvo Group', 'Nordea', 'Handelsbanken', 'Swedbank', 'Northvolt', 'King', 'TDA Creative', 'AFRY', 'CGI',  'IBM', 'Amazon', 'Google', 'Microsoft']

print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("FS_jobs_sweden.json")
# Out:
# Country:  Sweden
#
# Company 1: SimpleSign
#          Job 1: Backend-utvecklare downloaded!
#          Job 2: Fullstack Engineer downloaded!
#          Job 3: CTO downloaded!
#          Job 4: Full Stack Engineer downloaded!
#          Job 5: Backend-utvecklare downloaded!
#          Job 6: Fullstack Engineer downloaded!
#          Job 7: CTO downloaded!
#          Job 8: Full Stack Engineer downloaded!
#          Job 9: Back End-utvecklare downloaded!
#          Job 10: Backend-utvecklare downloaded!
#          Job 11: CTO downloaded!
#          Job 12: Backend-utvecklare downloaded!
#          Job 13: Fullstack Engineer downloaded!
#          Job 14: Backend-utvecklare downloaded!
#          Job 15: Fullstack Engineer downloaded!
#          Job 16: CTO downloaded!
#          Job 17: Backend-utvecklare downloaded!
#          Job 18: Fullstack Engineer downloaded!
#          Job 19: CTO downloaded!
#          Job 20: Full Stack Engineer downloaded!
#          Job 21: Back End-utvecklare downloaded!
# Company 2: InterEx Group
#          Job 1: Cloud Engineer downloaded!
# Company 3: Iver Sverige
#          No jobs found for Iver Sverige
# Company 4: HCLTech
#          Job 1: FSO Engineer downloaded!
# Company 5: Fortnox
#          Job 1: Software Developer downloaded!
# Company 6: Orbis
#          Job 1: Stockholm (in-house) Senior DevOps Engineer – SaaS Platform - (Hybrid) downloaded!
# Company 7: Lynk & Co
#          No jobs found for Lynk & Co
# Company 8: Swedbank
#          Job 1: Strategic Project Lead to Swedbank’s Group Strategy Team downloaded!
#          Job 2: Junior Credit Research Analyst downloaded!
#          Job 3: Strategic Project Lead to Swedbank’s Group Strategy Team downloaded!
#          Job 4: Junior Credit Research Analyst downloaded!
#          Job 5: Strategic Project Lead to Swedbank’s Group Strategy Team downloaded!
#          Job 6: Junior Credit Research Analyst downloaded!
#          Job 7: Strategic Project Lead to Swedbank’s Group Strategy Team downloaded!
#          Job 8: Junior Credit Research Analyst downloaded!
#          Job 9: Strategic Project Lead to Swedbank’s Group Strategy Team downloaded!
#          Job 10: Junior Credit Research Analyst downloaded!
# Company 9: Computer Futures
#          Job 1: Data Specialist downloaded!
#          Job 2: Lead/Senior Frontend Engineer downloaded!
#          Job 3: COBOL Developer downloaded!
#          Job 4: Software Engineer (Golang) downloaded!
#          Job 5: Lead/Senior Backend Engineer downloaded!
#          Job 6: Senior Data Engineer downloaded!
#          Job 7: Cobol Programmer downloaded!
#          Job 8: Senior Data Engineer downloaded!
#          Job 9: Lead/Senior Software Engineer downloaded!
#          Job 10: Senior Software Engineer/Data & Analytics downloaded!
#          Job 11: Data Specialist downloaded!
#          Job 12: Lead/Senior Frontend Engineer downloaded!
#          Job 13: COBOL Developer downloaded!
#          Job 14: Software Engineer (Golang) downloaded!
#          Job 15: Lead/Senior Backend Engineer downloaded!
#          Job 16: Senior Data Engineer downloaded!
#          Job 17: Cobol Programmer downloaded!
#          Job 18: Senior Data Engineer downloaded!
#          Job 19: Lead/Senior Software Engineer downloaded!
# Company 10: HiQ
#          Job 1: Front-end Developer downloaded!
#          Job 2: Junior Project Manager downloaded!
#          Job 3: Great coworker wanted! downloaded!
#          Job 4: Project Manager downloaded!
#          Job 5: BI Developer downloaded!
#          Job 6: Project Manager downloaded!
#          Job 7: Fullstack Developer downloaded!
#          Job 8: Optimizely Developer downloaded!
#          Job 9: Software Developer, C, C++, Python downloaded!
#          Job 10: Data Engineer downloaded!
#          Job 11: Projektledare IT downloaded!
#          Job 12: Embedded Developer downloaded!
#          Job 13: Front-end Developer downloaded!
#          Job 14: Junior Project Manager downloaded!
#          Job 15: Great coworker wanted! downloaded!
#          Job 16: Project Manager downloaded!
#          Job 17: BI Developer downloaded!
#          Job 18: Project Manager downloaded!
#          Job 19: Fullstack Developer downloaded!
#          Job 20: Fullstack Developer downloaded!
#          Job 21: Fullstack Developer downloaded!
#          Job 22: Optimizely Developer downloaded!
#          Job 23: Embedded Developer downloaded!
#          Job 24: Embedded Software Developer downloaded!
#          Job 25: Software Tester downloaded!
#          Job 26: Solution Architect downloaded!
#          Job 27: Join us in Västerås! downloaded!
#          Job 28: DevOps or OpsDev downloaded!
#          Job 29: DevOps downloaded!
#          Job 30: Software Developer till det kreativa IT-konsultbolaget HiQ downloaded!
#          Job 31: IT-konsult downloaded!
#          Job 32: Embedded Software Developer downloaded!
#          Job 33: C++ Developer/Autonomous Driving downloaded!
#          Job 34: Front-end Developer downloaded!
#          Job 35: Junior Project Manager downloaded!
#          Job 36: Optimizely Developer downloaded!
#          Job 37: Software Developer, C, C++, Python downloaded!
#          Job 38: Project Manager downloaded!
#          Job 39: BI Developer downloaded!
#          Job 40: Optimizely Developer downloaded!
#          Job 41: Data Engineer downloaded!
#          Job 42: Projektledare IT downloaded!
#          Job 43: SCRUM Master downloaded!
#          Job 44: Embedded Developer downloaded!
#          Job 45: Front-end Developer downloaded!
#          Job 46: Junior Project Manager downloaded!
#          Job 47: Project Manager downloaded!
#          Job 48: BI Developer downloaded!
#          Job 49: Fullstack Developer downloaded!
#          Job 50: Fullstack Developer downloaded!
#          Job 51: Optimizely Developer downloaded!
#          Job 52: Software Developer, C, C++, Python downloaded!
#          Job 53: SCRUM Master downloaded!
#          Job 54: Embedded Developer downloaded!
#          Job 55: Front-end Developer downloaded!
#          Job 56: Junior Project Manager downloaded!
#          Job 57: Great coworker wanted! downloaded!
#          Job 58: Project Manager downloaded!
#          Job 59: BI Developer downloaded!
#          Job 60: Project Manager downloaded!
#          Job 61: Fullstack Developer downloaded!
#          Job 62: Fullstack Developer downloaded!
#          Job 63: Fullstack Developer downloaded!
#          Job 64: Optimizely Developer downloaded!
#          Job 65: Projektledare IT downloaded!
#          Job 66: Embedded Developer downloaded!
#          Job 67: Front-end Developer downloaded!
#          Job 68: Junior Project Manager downloaded!
#          Job 69: Fullstack Developer downloaded!
#          Job 70: Fullstack Developer downloaded!
#          Job 71: Optimizely Developer downloaded!
#          Job 72: Software Developer, C, C++, Python downloaded!
#          Job 73: Data Engineer downloaded!
#          Job 74: Embedded Developer downloaded!
#          Job 75: Front-end Developer downloaded!
#          Job 76: Junior Project Manager downloaded!
#          Job 77: Great coworker wanted! downloaded!
#          Job 78: Project Manager downloaded!
#          Job 79: Fullstack Developer downloaded!
#          Job 80: Fullstack Developer downloaded!
#          Job 81: Fullstack Developer downloaded!
#          Job 82: Optimizely Developer downloaded!
#          Job 83: Software Developer, C, C++, Python downloaded!
#          Job 84: Data Engineer downloaded!
#          Job 85: Projektledare IT downloaded!
#          Job 86: SCRUM Master downloaded!
#          Job 87: Embedded Developer downloaded!
#          Job 88: Front-end Developer downloaded!
#          Job 89: Junior Project Manager downloaded!
#          Job 90: Great coworker wanted! downloaded!
#          Job 91: Project Manager downloaded!
#          Job 92: BI Developer downloaded!
#          Job 93: Project Manager downloaded!
#          Job 94: Fullstack Developer downloaded!
#          Job 95: Fullstack Developer downloaded!
#          Job 96: Fullstack Developer downloaded!
#          Job 97: Optimizely Developer downloaded!
#          Job 98: SCRUM Master downloaded!
#          Job 99: Embedded Developer downloaded!
#          Job 100: Front-end Developer downloaded!
#          Job 101: Junior Project Manager downloaded!
#          Job 102: Great coworker wanted! downloaded!
#          Job 103: Project Manager downloaded!
#          Job 104: Fullstack Developer downloaded!
#          Job 105: Fullstack Developer downloaded!
#          Job 106: Fullstack Developer downloaded!
#          Job 107: Optimizely Developer downloaded!
#          Job 108: Embedded Developer downloaded!
#          Job 109: Front-end Developer downloaded!
#          Job 110: Junior Project Manager downloaded!
#          Job 111: Great coworker wanted! downloaded!
#          Job 112: Data Engineer downloaded!
#          Job 113: Projektledare IT downloaded!
#          Job 114: SCRUM Master downloaded!
#          Job 115: Embedded Developer downloaded!
#          Job 116: Project Manager downloaded!
#          Job 117: Fullstack Developer downloaded!
#          Job 118: Fullstack Developer downloaded!
#          Job 119: Fullstack Developer downloaded!
#          Job 120: Optimizely Developer downloaded!
#          Job 121: Data Engineer downloaded!
#          Job 122: Embedded Developer downloaded!
#          Job 123: Front-end Developer downloaded!
#          Job 124: Project Manager downloaded!
#          Job 125: Projektledare IT downloaded!
#          Job 126: SCRUM Master downloaded!
#          Job 127: Embedded Developer downloaded!
#          Job 128: Front-end Developer downloaded!
#          Job 129: Junior Project Manager downloaded!
#          Job 130: Project Manager downloaded!
#          Job 131: Fullstack Developer downloaded!
#          Job 132: Fullstack Developer downloaded!
#          Job 133: Fullstack Developer downloaded!
#          Job 134: Optimizely Developer downloaded!
#          Job 135: Software Developer, C, C++, Python downloaded!
#          Job 136: Data Engineer downloaded!
#          Job 137: Embedded Developer downloaded!
#          Job 138: Front-end Developer downloaded!
#          Job 139: Junior Project Manager downloaded!
#          Job 140: Great coworker wanted! downloaded!
#          Job 141: Project Manager downloaded!
#          Job 142: BI Developer downloaded!
#          Job 143: Project Manager downloaded!
#          Job 144: Fullstack Developer downloaded!
#          Job 145: Fullstack Developer downloaded!
#          Job 146: Optimizely Developer downloaded!
#          Job 147: Software Developer, C, C++, Python downloaded!
#          Job 148: Data Engineer downloaded!
#          Job 149: Projektledare IT downloaded!
#          Job 150: Junior Project Manager downloaded!
#          Job 151: Great coworker wanted! downloaded!
#          Job 152: Project Manager downloaded!
#          Job 153: BI Developer downloaded!
#          Job 154: Project Manager downloaded!
#          Job 155: Fullstack Developer downloaded!
#          Job 156: Fullstack Developer downloaded!
#          Job 157: Projektledare IT downloaded!
#          Job 158: SCRUM Master downloaded!
#          Job 159: Embedded Developer downloaded!
#          Job 160: Front-end Developer downloaded!
#          Job 161: Fullstack Developer downloaded!
#          Job 162: Fullstack Developer downloaded!
#          Job 163: Fullstack Developer downloaded!
#          Job 164: Optimizely Developer downloaded!
#          Job 165: Data Engineer downloaded!
#          Job 166: Embedded Developer downloaded!
#          Job 167: Front-end Developer downloaded!
#          Job 168: Junior Project Manager downloaded!
#          Job 169: Great coworker wanted! downloaded!
#          Job 170: Optimizely Developer downloaded!
#          Job 171: Software Developer, C, C++, Python downloaded!
#          Job 172: Data Engineer downloaded!
#          Job 173: Projektledare IT downloaded!
#          Job 174: SCRUM Master downloaded!
#          Job 175: Embedded Developer downloaded!
#          Job 176: Junior Project Manager downloaded!
#          Job 177: Great coworker wanted! downloaded!
#          Job 178: Project Manager downloaded!
#          Job 179: BI Developer downloaded!
#          Job 180: Project Manager downloaded!
#          Job 181: Fullstack Developer downloaded!
#          Job 182: Software Developer, C, C++, Python downloaded!
#          Job 183: Data Engineer downloaded!
#          Job 184: Projektledare IT downloaded!
#          Job 185: SCRUM Master downloaded!
# Company 11: Canonical
#          Job 1: Manager - Web and Design Project Management downloaded!
#          Job 2: Web Developer downloaded!
#          Job 3: Web Developer downloaded!
#          Job 4: Community Engineer downloaded!
#          Job 5: Technical Author - Ubuntu and Canonical products downloaded!
#          Job 6: Executive Assistant downloaded!
#          Job 7: SDR team manager downloaded!
#          Job 8: Manager, Talent Science downloaded!
#          Job 9: Graduate Product Marketing Manager downloaded!
#          Job 10: Software Engineer - Data Infrastructure downloaded!
#          Job 11: Engineering Manager, Ubuntu Server Distribution downloaded!
#          Job 12: Software Engineer - Ubuntu Core downloaded!
#          Job 13: Software Engineering Manager - Ubuntu Build Infrastructure downloaded!
#          Job 14: Senior Observability Platform Developer - Python/Go downloaded!
#          Job 15: Software Engineer - Data Infrastructure - OpenSearch/ElasticSearch downloaded!
#          Job 16: Embedded Linux Containers Software Engineer downloaded!
#          Job 17: Field Software Engineer - EMEA downloaded!
#          Job 18: Senior Software Engineer - Digital Workplace downloaded!
#          Job 19: Executive Assistant downloaded!
#          Job 20: Marketing operations specialist downloaded!
#          Job 21: Manager - Web and Design Project Management downloaded!
#          Job 22: Web Developer downloaded!
#          Job 23: Web Developer downloaded!
#          Job 24: Developer Relations Manager downloaded!
#          Job 25: Manager, Talent Science downloaded!
#          Job 26: Graduate Product Marketing Manager downloaded!
#          Job 27: Performance Marketing Manager downloaded!
#          Job 28: Talent Analytics Lead downloaded!
#          Job 29: Product Marketing Lead downloaded!
#          Job 30: Executive Assistant downloaded!
#          Job 31: Marketing operations specialist downloaded!
#          Job 32: Manager - Web and Design Project Management downloaded!
#          Job 33: Web Developer downloaded!
#          Job 34: Web Developer downloaded!
#          Job 35: Chief Information Security Officer downloaded!
#          Job 36: SDR team manager downloaded!
#          Job 37: Manager, Talent Science downloaded!
#          Job 38: Performance Marketing Manager downloaded!
#          Job 39: Talent Analytics Lead downloaded!
#          Job 40: Product Marketing Lead downloaded!
#          Job 41: Technical Author - Ubuntu and Canonical products downloaded!
#          Job 42: Executive Assistant downloaded!
#          Job 43: Marketing operations specialist downloaded!
#          Job 44: Manager - Web and Design Project Management downloaded!
#          Job 45: Web Developer downloaded!
#          Job 46: Community Engineer downloaded!
#          Job 47: Web Developer downloaded!
#          Job 48: Chief Information Security Officer downloaded!
#          Job 49: SDR team manager downloaded!
#          Job 50: Graduate Product Marketing Manager downloaded!
#          Job 51: Manager, Talent Science downloaded!
#          Job 52: Performance Marketing Manager downloaded!
#          Job 53: Talent Analytics Lead downloaded!
#          Job 54: Product Marketing Lead downloaded!
#          Job 55: Silicon Alliances Business Development Lead downloaded!
#          Job 56: Executive Assistant downloaded!
#          Job 57: Marketing operations specialist downloaded!
#          Job 58: Manager - Web and Design Project Management downloaded!
#          Job 59: Web Developer downloaded!
#          Job 60: Web Developer downloaded!
#          Job 61: Chief Information Security Officer downloaded!
#          Job 62: SDR team manager downloaded!
#          Job 63: Developer Relations Manager downloaded!
#          Job 64: Manager, Talent Science downloaded!
#          Job 65: Graduate Product Marketing Manager downloaded!
#          Job 66: Performance Marketing Manager downloaded!
#          Job 67: Talent Analytics Lead downloaded!
#          Job 68: Product Marketing Lead downloaded!
#          Job 69: Community Engineer downloaded!
#          Job 70: Executive Assistant downloaded!
#          Job 71: Manager - Web and Design Project Management downloaded!
#          Job 72: Web Developer downloaded!
#          Job 73: Web Developer downloaded!
#          Job 74: Graduate Product Marketing Manager downloaded!
#          Job 75: Chief Information Security Officer downloaded!
#          Job 76: SDR team manager downloaded!
#          Job 77: Performance Marketing Manager downloaded!
#          Job 78: Talent Analytics Lead downloaded!
#          Job 79: Product Marketing Lead downloaded!
#          Job 80: Community Engineer downloaded!
#          Job 81: Technical Author - Ubuntu and Canonical products downloaded!
#          Job 82: Executive Assistant downloaded!
#          Job 83: Marketing operations specialist downloaded!
#          Job 84: Manager - Web and Design Project Management downloaded!
#          Job 85: Web Developer downloaded!
#          Job 86: Community Engineer downloaded!
#          Job 87: Web Developer downloaded!
#          Job 88: Graduate Product Marketing Manager downloaded!
#          Job 89: Manager, Talent Science downloaded!
#          Job 90: Performance Marketing Manager downloaded!
#          Job 91: Talent Analytics Lead downloaded!
#          Job 92: Marketing operations specialist downloaded!
#          Job 93: Manager - Web and Design Project Management downloaded!
#          Job 94: Web Developer downloaded!
#          Job 95: Web Developer downloaded!
#          Job 96: Chief Information Security Officer downloaded!
#          Job 97: SDR team manager downloaded!
#          Job 98: Developer Relations Manager downloaded!
#          Job 99: Manager, Talent Science downloaded!
#          Job 100: Graduate Product Marketing Manager downloaded!
#          Job 101: Performance Marketing Manager downloaded!
#          Job 102: Talent Analytics Lead downloaded!
#          Job 103: Product Marketing Lead downloaded!
#          Job 104: Community Engineer downloaded!
#          Job 105: Executive Assistant downloaded!
#          Job 106: Marketing operations specialist downloaded!
#          Job 107: Manager - Web and Design Project Management downloaded!
#          Job 108: Web Developer downloaded!
#          Job 109: Web Developer downloaded!
#          Job 110: Graduate Product Marketing Manager downloaded!
#          Job 111: Performance Marketing Manager downloaded!
#          Job 112: Talent Analytics Lead downloaded!
#          Job 113: Product Marketing Lead downloaded!
#          Job 114: Community Engineer downloaded!
#          Job 115: Manager - Web and Design Project Management downloaded!
#          Job 116: Web Developer downloaded!
#          Job 117: Community Engineer downloaded!
#          Job 118: Web Developer downloaded!
#          Job 119: Chief Information Security Officer downloaded!
#          Job 120: SDR team manager downloaded!
#          Job 121: Performance Marketing Manager downloaded!
#          Job 122: Talent Analytics Lead downloaded!
#          Job 123: Product Marketing Lead downloaded!
#          Job 124: Silicon Alliances Business Development Lead downloaded!
# Company 12: Nexer Group
#          Job 1: Network Architect for Industrial ILAN (IT/OT) to Scania downloaded!
#          Job 2: Utvecklare till Saab Electronic Warfare downloaded!
#          Job 3: Intelligent Automation Product Owner to Cary Group downloaded!
#          Job 4: Mjukvaruutvecklare till Saab Surveillance downloaded!
#          Job 5: Junior CI/CD utvecklare till Saab Survelliance downloaded!
#          Job 6: Linux System Administrator to Etraveli Group downloaded!
#          Job 7: Network Architect for Industrial ILAN (IT/OT) to Scania downloaded!
#          Job 8: Junior systemintegratör inom automotive downloaded!
#          Job 9: Group IT Manager to ZetaDisplay downloaded!
#          Job 10: Intelligent Automation Product Owner to Cary Group downloaded!
#          Job 11: Linux System Administrator to Etraveli Group downloaded!
#          Job 12: Linuxutvecklare till Saab Surveillance downloaded!
#          Job 13: Network Architect for Industrial ILAN (IT/OT) to Scania downloaded!
# Company 13: Enfo
#          Job 1: IAM Architect Nordics downloaded!
#          Job 2: Fullstack Developer downloaded!
#          Job 3: AWS Cloud Architect downloaded!
#          Job 4: IAM Consultant Nordics downloaded!
#          Job 5: Integration Developer downloaded!
#          Job 6: IAM Architect Nordics downloaded!
#          Job 7: Fullstack Developer downloaded!
#          Job 8: AWS Cloud Architect downloaded!
#          Job 9: IAM Consultant Nordics downloaded!
#          Job 10: Integration Developer downloaded!
#          Job 11: IAM Architect Nordics downloaded!
#          Job 12: Fullstack Developer downloaded!
#          Job 13: AWS Cloud Architect downloaded!
#          Job 14: IAM Consultant Nordics downloaded!
#          Job 15: Integration Developer downloaded!
#          Job 16: IAM Architect Nordics downloaded!
#          Job 17: Fullstack Developer downloaded!
#          Job 18: AWS Cloud Architect downloaded!
#          Job 19: IAM Consultant Nordics downloaded!
#          Job 20: Integration Developer downloaded!
#          Job 21: IAM Architect Nordics downloaded!
# Company 14: tretton37
#          No jobs found for tretton37
# Company 15: Tietoevry
#          No jobs found for Tietoevry
# Company 16: Fortnox
#          Job 1: Software Developer downloaded!
#          Job 2: Software Developer downloaded!
#          Job 3: Fullstack Developer downloaded!
# Company 17: HiQ
#          Job 1: Senior Tester downloaded!
#          Job 2: HiQ söker C, C++ Utvecklare downloaded!
#          Job 3: Software Developer, C, C++, Python downloaded!
#          Job 4: Great coworker wanted! downloaded!
#          Job 5: .Net Developer downloaded!
#          Job 6: Fullstack Developer downloaded!
#          Job 7: Sitevision Developer downloaded!
#          Job 8: Node.js Developer downloaded!
#          Job 9: Front-end Developer downloaded!
#          Job 10: Project Manager downloaded!
#          Job 11: BI Developer downloaded!
#          Job 12: Project Manager downloaded!
#          Job 13: Optimizely Developer downloaded!
#          Job 14: Fullstack Developer downloaded!
#          Job 15: System Developer downloaded!
#          Job 16: Great coworker wanted! downloaded!
#          Job 17: Fullstack Developer downloaded!
# Company 18: Boeing
#          No jobs found for Boeing
# Company 19: Bluestep Bank
#          No jobs found for Bluestep Bank
# Company 20: Telavox
#          Job 1: Fullstack Software Developer downloaded!
#          Job 2: Software Developer (Lead) downloaded!
#          Job 3: IT Technician downloaded!
#          Job 4: Fullstack Software Developer downloaded!
#          Job 5: Experienced Front-End Developer downloaded!
#          Job 6: DevOps Engineer downloaded!
#          Job 7: Engineering Manager downloaded!
#          Job 8: Software Developer (Lead) downloaded!
#          Job 9: Experienced Front-end Developer downloaded!
#          Job 10: Engineering Manager to Telavox downloaded!
#          Job 11: IT Technician downloaded!
#          Job 12: Fullstack Software Developer downloaded!
#          Job 13: Backend Developer to successful SaaS company downloaded!
#          Job 14: Experienced Front-End Developer downloaded!
#          Job 15: Senior BI Developer downloaded!
#          Job 16: DevOps Engineer downloaded!
#          Job 17: Software Developer (Lead) downloaded!
#          Job 18: Fullstack Software Developer downloaded!
#          Job 19: Engineering Manager downloaded!
#          Job 20: Software Developer (Lead) downloaded!
#          Job 21: Experienced Front-end Developer downloaded!
#          Job 22: Engineering Manager to Telavox downloaded!
#          Job 23: IT Technician downloaded!
#          Job 24: Fullstack Software Developer downloaded!
#          Job 25: Backend Developer to successful SaaS company downloaded!
#          Job 26: Experienced Front-End Developer downloaded!
#          Job 27: Senior BI Developer downloaded!
#          Job 28: DevOps Engineer downloaded!
#          Job 29: Software Developer (Lead) downloaded!
#          Job 30: Fullstack Software Developer downloaded!
#          Job 31: Engineering Manager downloaded!
#          Job 32: Software Developer (Lead) downloaded!
#          Job 33: Experienced Front-end Developer downloaded!
#          Job 34: Engineering Manager to Telavox downloaded!
#          Job 35: IT Technician downloaded!
#          Job 36: Fullstack Software Developer downloaded!
#          Job 37: Backend Developer to successful SaaS company downloaded!
#          Job 38: Experienced Front-End Developer downloaded!
#          Job 39: Senior BI Developer downloaded!
#          Job 40: DevOps Engineer downloaded!
#          Job 41: Software Developer (Lead) downloaded!
#          Job 42: Fullstack Software Developer downloaded!
#          Job 43: Engineering Manager downloaded!
#          Job 44: Software Developer (Lead) downloaded!
#          Job 45: Experienced Front-end Developer downloaded!
#          Job 46: Engineering Manager to Telavox downloaded!
#          Job 47: IT Technician downloaded!
#          Job 48: Fullstack Software Developer downloaded!
#          Job 49: Backend Developer to successful SaaS company downloaded!
#          Job 50: Experienced Front-End Developer downloaded!
#          Job 51: Senior BI Developer downloaded!
#          Job 52: DevOps Engineer downloaded!
#          Job 53: Software Developer (Lead) downloaded!
#          Job 54: Fullstack Software Developer downloaded!
#          Job 55: Engineering Manager downloaded!
#          Job 56: Software Developer (Lead) downloaded!
#          Job 57: Experienced Front-end Developer downloaded!
#          Job 58: Engineering Manager to Telavox downloaded!
#          Job 59: IT Technician downloaded!
#          Job 60: Fullstack Software Developer downloaded!
#          Job 61: Backend Developer to successful SaaS company downloaded!
#          Job 62: Experienced Front-End Developer downloaded!
#          Job 63: Senior BI Developer downloaded!
#          Job 64: DevOps Engineer downloaded!
#          Job 65: Software Developer (Lead) downloaded!
#          Job 66: Fullstack Software Developer downloaded!
#          Job 67: Engineering Manager to Telavox downloaded!
#          Job 68: IT Technician downloaded!
#          Job 69: Fullstack Software Developer downloaded!
#          Job 70: Backend Developer to successful SaaS company downloaded!
#          Job 71: Experienced Front-End Developer downloaded!
#          Job 72: Senior BI Developer downloaded!
#          Job 73: DevOps Engineer downloaded!
#          Job 74: Software Developer (Lead) downloaded!
#          Job 75: Fullstack Software Developer downloaded!
#          Job 76: Engineering Manager downloaded!
#          Job 77: Software Developer (Lead) downloaded!
#          Job 78: Experienced Front-end Developer downloaded!
#          Job 79: Engineering Manager to Telavox downloaded!
#          Job 80: IT Technician downloaded!
#          Job 81: Fullstack Software Developer downloaded!
#          Job 82: Backend Developer to successful SaaS company downloaded!
#          Job 83: Experienced Front-End Developer downloaded!
#          Job 84: Senior BI Developer downloaded!
#          Job 85: DevOps Engineer downloaded!
#          Job 86: Software Developer (Lead) downloaded!
#          Job 87: Fullstack Software Developer downloaded!
#          Job 88: Engineering Manager downloaded!
#          Job 89: Software Developer (Lead) downloaded!
#          Job 90: Experienced Front-end Developer downloaded!
#          Job 91: IT Technician downloaded!
#          Job 92: Fullstack Software Developer downloaded!
#          Job 93: Backend Developer to successful SaaS company downloaded!
#          Job 94: Experienced Front-End Developer downloaded!
#          Job 95: Senior BI Developer downloaded!
#          Job 96: DevOps Engineer downloaded!
#          Job 97: Software Developer (Lead) downloaded!
#          Job 98: Experienced Front-end Developer downloaded!
#          Job 99: Engineering Manager to Telavox downloaded!
#          Job 100: IT Technician downloaded!
#          Job 101: Fullstack Software Developer downloaded!
#          Job 102: Backend Developer to successful SaaS company downloaded!
#          Job 103: Experienced Front-End Developer downloaded!
#          Job 104: Senior BI Developer downloaded!
#          Job 105: DevOps Engineer downloaded!
#          Job 106: Software Developer (Lead) downloaded!
#          Job 107: Fullstack Software Developer downloaded!
#          Job 108: Engineering Manager downloaded!
#          Job 109: Software Developer (Lead) downloaded!
#          Job 110: Experienced Front-end Developer downloaded!
#          Job 111: Engineering Manager to Telavox downloaded!
#          Job 112: IT Technician downloaded!
#          Job 113: Fullstack Software Developer downloaded!
#          Job 114: DevOps Engineer downloaded!
#          Job 115: Software Developer (Lead) downloaded!
#          Job 116: Fullstack Software Developer downloaded!
#          Job 117: Engineering Manager downloaded!
#          Job 118: Software Developer (Lead) downloaded!
#          Job 119: Experienced Front-end Developer downloaded!
# Company 21: Klarna
#          Job 1: Product Manager - Platform Products downloaded!
#          Job 2: Product Manager - Consumer Products downloaded!
#          Job 3: Product Manager - AdTech Products downloaded!
#          Job 4: Software Engineer - Java downloaded!
#          Job 5: Director, Global Vendor Operations downloaded!
#          Job 6: Vendor Governance Manager downloaded!
#          Job 7: Senior Product Manager - Platform Products downloaded!
#          Job 8: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 9: Disaster Recovery Manager downloaded!
#          Job 10: Customer Service Representative - German Speaking downloaded!
#          Job 11: Senior Software Engineer - Java downloaded!
#          Job 12: Senior Software Engineer - JavaScript downloaded!
#          Job 13: Senior Developer - JavaScript - Search & Compare downloaded!
#          Job 14: Senior Software Engineer - Functional Programming downloaded!
#          Job 15: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 16: Engineering Manager - iOS / Android downloaded!
#          Job 17: Product Manager - Platform Products downloaded!
#          Job 18: Product Manager - Consumer Products downloaded!
#          Job 19: Product Manager - AdTech Products downloaded!
#          Job 20: Software Engineer - Java downloaded!
#          Job 21: Director, Global Vendor Operations downloaded!
#          Job 22: Vendor Governance Manager downloaded!
#          Job 23: Senior Product Manager - Platform Products downloaded!
#          Job 24: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 25: Disaster Recovery Manager downloaded!
#          Job 26: Customer Service Representative - German Speaking downloaded!
#          Job 27: Senior Software Engineer - Java downloaded!
#          Job 28: Senior Software Engineer - JavaScript downloaded!
#          Job 29: Senior Developer - JavaScript - Search & Compare downloaded!
#          Job 30: Senior Software Engineer - Functional Programming downloaded!
#          Job 31: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 32: Engineering Manager - iOS / Android downloaded!
#          Job 33: Product Manager - Platform Products downloaded!
#          Job 34: Software Engineer - Java downloaded!
#          Job 35: Director, Global Vendor Operations downloaded!
#          Job 36: Vendor Governance Manager downloaded!
#          Job 37: Senior Product Manager - Platform Products downloaded!
#          Job 38: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 39: Disaster Recovery Manager downloaded!
#          Job 40: Customer Service Representative - German Speaking downloaded!
#          Job 41: Senior Software Engineer - Java downloaded!
#          Job 42: Senior Software Engineer - JavaScript downloaded!
#          Job 43: Senior Developer - JavaScript - Search & Compare downloaded!
#          Job 44: Senior Software Engineer - Functional Programming downloaded!
#          Job 45: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 46: Engineering Manager - iOS / Android downloaded!
#          Job 47: Product Manager - Platform Products downloaded!
#          Job 48: Product Manager - Consumer Products downloaded!
#          Job 49: Product Manager - AdTech Products downloaded!
#          Job 50: Software Engineer - Java downloaded!
#          Job 51: Director, Global Vendor Operations downloaded!
#          Job 52: Vendor Governance Manager downloaded!
#          Job 53: Senior Product Manager - Platform Products downloaded!
#          Job 54: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 55: Disaster Recovery Manager downloaded!
#          Job 56: Customer Service Representative - German Speaking downloaded!
#          Job 57: Senior Software Engineer - Java downloaded!
#          Job 58: Senior Software Engineer - JavaScript downloaded!
#          Job 59: Senior Developer - JavaScript - Search & Compare downloaded!
#          Job 60: Senior Software Engineer - Functional Programming downloaded!
#          Job 61: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 62: Engineering Manager - iOS / Android downloaded!
#          Job 63: Product Manager - Platform Products downloaded!
#          Job 64: Product Manager - Consumer Products downloaded!
#          Job 65: Product Manager - AdTech Products downloaded!
#          Job 66: Software Engineer - Java downloaded!
#          Job 67: Director, Global Vendor Operations downloaded!
#          Job 68: Vendor Governance Manager downloaded!
#          Job 69: Senior Product Manager - Platform Products downloaded!
#          Job 70: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 71: Disaster Recovery Manager downloaded!
#          Job 72: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 73: Engineering Manager - iOS / Android downloaded!
#          Job 74: Product Manager - Platform Products downloaded!
#          Job 75: Product Manager - Consumer Products downloaded!
#          Job 76: Director, Global Vendor Operations downloaded!
#          Job 77: Vendor Governance Manager downloaded!
#          Job 78: Senior Product Manager - Platform Products downloaded!
#          Job 79: Portfolio Credit Risk Senior Analyst downloaded!
#          Job 80: Disaster Recovery Manager downloaded!
#          Job 81: Customer Service Representative - German Speaking downloaded!
#          Job 82: Senior Software Engineer - Java downloaded!
#          Job 83: Senior Software Engineer - JavaScript downloaded!
#          Job 84: Product Manager - Platform Products downloaded!
#          Job 85: Product Manager - Consumer Products downloaded!
#          Job 86: Product Manager - AdTech Products downloaded!
#          Job 87: Software Engineer - Java downloaded!
#          Job 88: Senior Software Engineer - JavaScript downloaded!
#          Job 89: Senior Developer - JavaScript - Search & Compare downloaded!
#          Job 90: Senior Software Engineer - Functional Programming downloaded!
#          Job 91: Senior Software Engineer - DevOps - Public API Gateway downloaded!
#          Job 92: Engineering Manager - iOS / Android downloaded!
# Company 22: Scania
#          Job 1: Online Editor downloaded!
#          Job 2: Business Controller for Scania Purchasing downloaded!
#          Job 3: Are you our next Project Manager at Scania Project Office? downloaded!
#          Job 4: Quality Engineer - Battery Production downloaded!
#          Job 5: Online Editor downloaded!
#          Job 6: Quality Engineer - Battery Production downloaded!
# Company 23: Volvo Group
#          No jobs found for Volvo Group
# Company 24: Nordea
#          Job 1: Head of Data, in Financial Crime Intelligence, Investigations & Analytics (FCIIA) downloaded!
#          Job 2: IT Infrastructure Specialist - Nordea Life & Pension downloaded!
#          Job 3: Project Manager to drive Strategic Technical Deliveries downloaded!
#          Job 4: Complex Intelligence Analyst downloaded!
#          Job 5: Senior Data Engineer for AI and BI data development downloaded!
#          Job 6: Quantexa Developer downloaded!
#          Job 7: IT Security Specialist IAM downloaded!
#          Job 8: Senior IT Security Specialist downloaded!
#          Job 9: Head of Oracle Database Engineering downloaded!
# Company 25: Handelsbanken
#          Job 1: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 2: Androidutvecklare till Handelsbanken i Malmö downloaded!
#          Job 3: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 4: Nätverksspecialist till Handelsbanken downloaded!
#          Job 5: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 6: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 7: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 8: Backendutvecklare för Handelsbankens mobiltjänster downloaded!
#          Job 9: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 10: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 11: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 12: Nätverksspecialist till Handelsbanken downloaded!
#          Job 13: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 14: Backendutvecklare till Handelsbanken Stockholm downloaded!
#          Job 15: Senior Data/ML Engineer to Advanced Analytics and AI Department downloaded!
#          Job 16: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 17: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 18: Backendutvecklare för Handelsbankens mobiltjänster downloaded!
#          Job 19: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 20: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 21: Androidutvecklare till Handelsbanken i Malmö downloaded!
#          Job 22: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 23: Nätverksspecialist till Handelsbanken downloaded!
#          Job 24: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 25: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 26: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 27: Backendutvecklare för Handelsbankens mobiltjänster downloaded!
#          Job 28: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 29: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 30: Senior Javautvecklare downloaded!
#          Job 31: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 32: Androidutvecklare till Handelsbanken i Malmö downloaded!
#          Job 33: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 34: Nätverksspecialist till Handelsbanken downloaded!
#          Job 35: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 36: Senior Data/ML Engineer to Advanced Analytics and AI Department downloaded!
#          Job 37: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 38: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 39: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 40: Nätverksspecialist till Handelsbanken downloaded!
#          Job 41: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 42: Backendutvecklare till Handelsbanken Stockholm downloaded!
#          Job 43: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 44: Backendutvecklare för Handelsbankens mobiltjänster downloaded!
#          Job 45: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 46: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 47: Senior Javautvecklare downloaded!
#          Job 48: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 49: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 50: Backendutvecklare till Handelsbanken Stockholm downloaded!
#          Job 51: Senior Data/ML Engineer to Advanced Analytics and AI Department downloaded!
#          Job 52: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 53: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 54: Senior Javautvecklare downloaded!
#          Job 55: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 56: Androidutvecklare till Handelsbanken i Malmö downloaded!
#          Job 57: DevOps Engineer till Handelsbanken i Stockholm downloaded!
#          Job 58: Engineering Team Lead to Advanced Analytics and AI Department downloaded!
#          Job 59: Backendutvecklare till Handelsbanken Stockholm downloaded!
#          Job 60: Senior Data/ML Engineer to Advanced Analytics and AI Department downloaded!
#          Job 61: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 62: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
#          Job 63: IT-arkitekt till Handelsbankens betalningsområde downloaded!
#          Job 64: Senior Javautvecklare downloaded!
#          Job 65: Javautvecklare till Handelsbanken i Stockholm downloaded!
#          Job 66: Androidutvecklare till Handelsbanken i Malmö downloaded!
#          Job 67: Senior Data/ML Engineer to Advanced Analytics and AI Department downloaded!
#          Job 68: SAS-utvecklare inom Financial Crime Prevention till Handelsbanken downloaded!
#          Job 69: Javautvecklare inom integrationsområdet till Handelsbanken downloaded!
# Company 26: Swedbank
#          No jobs found for Swedbank
# Company 27: Northvolt
#          Job 1: Process Operator - Operator Procesu Produkcji - Skellefteå, Szwecja downloaded!
#          Job 2: Mechanical Simulation Engineer (Junior level) downloaded!
#          Job 3: Electrochemical Test Intern downloaded!
#          Job 4: Process Operator - Operator Procesu Produkcji - Skellefteå, Szwecja downloaded!
#          Job 5: Electrochemical Test Intern downloaded!
#          Job 6: Process Operator - Manufacturing Associate downloaded!
#          Job 7: Mechanical Simulation Engineer (Junior level) downloaded!
#          Job 8: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 9: Process Operator - Operator Procesu Produkcji - Skellefteå, Szwecja downloaded!
#          Job 10: Mechanical Simulation Engineer (Junior level) downloaded!
#          Job 11: Process Engineer - Assembly & Formation (Junior - Senior Level) downloaded!
#          Job 12: Shift Manager - Kierownik Zmiany - Skellefteå, Szwecja downloaded!
#          Job 13: Systems engineering in Test & Validation - Internship downloaded!
#          Job 14: Process Operator - Manufacturing Associate downloaded!
# Company 28: King
#          Job 1: CFO in Helsingborg downloaded!
#          Job 2: Java Developer to interesting assignment! downloaded!
#          Job 3: Data Scientist downloaded!
#          Job 4: Java Developer to interesting assignment! downloaded!
#          Job 5: Data Scientist downloaded!
#          Job 6: CFO in Helsingborg downloaded!
#          Job 7: Build and Configuration Engineer downloaded!
#          Job 8: MRO Buyer downloaded!
#          Job 9: CFO in Helsingborg downloaded!
# Company 29: TDA Creative
#          Job 1: Software Engineer downloaded!
#          Job 2: Senior Software Engineer downloaded!
#          Job 3: Product Lead downloaded!
#          Job 4: Senior Software Engineer downloaded!
#          Job 5: Software Engineer downloaded!
#          Job 6: Software Engineer downloaded!
#          Job 7: Back End Developer downloaded!
#          Job 8: Data Engineer Trade AI Team downloaded!
#          Job 9: Software Engineer downloaded!
#          Job 10: Senior Software Engineer downloaded!
#          Job 11: Software Engineer downloaded!
#          Job 12: Software Engineer downloaded!
#          Job 13: Back End Developer downloaded!
#          Job 14: Data Engineer Trade AI Team downloaded!
#          Job 15: Software Engineer downloaded!
#          Job 16: Senior Software Engineer downloaded!
#          Job 17: Product Lead downloaded!
#          Job 18: Senior Software Engineer downloaded!
#          Job 19: Back End Developer downloaded!
#          Job 20: Data Engineer Trade AI Team downloaded!
#          Job 21: Software Engineer downloaded!
#          Job 22: Senior Software Engineer downloaded!
#          Job 23: Product Lead downloaded!
#          Job 24: Senior Software Engineer downloaded!
#          Job 25: Software Engineer downloaded!
#          Job 26: Software Engineer downloaded!
#          Job 27: Data Engineer Trade AI Team downloaded!
#          Job 28: Software Engineer downloaded!
#          Job 29: Software Engineer downloaded!
#          Job 30: Back End Developer downloaded!
#          Job 31: Data Engineer Trade AI Team downloaded!
#          Job 32: Software Engineer downloaded!
#          Job 33: Senior Software Engineer downloaded!
#          Job 34: Product Lead downloaded!
#          Job 35: Senior Software Engineer downloaded!
#          Job 36: Back End Developer downloaded!
#          Job 37: Data Engineer Trade AI Team downloaded!
#          Job 38: Software Engineer downloaded!
#          Job 39: Product Lead downloaded!
#          Job 40: Software Engineer downloaded!
#          Job 41: Software Engineer downloaded!
# Company 30: AFRY
#          No jobs found for AFRY
# Company 31: CGI
#          Job 1: Junior Utvecklare C# downloaded!
#          Job 2: Service Delivery Manager downloaded!
#          Job 3: Power BI-konsult! downloaded!
#          Job 4: Testare/Testledare till Sundsvall downloaded!
#          Job 5: Junior Utvecklare C# downloaded!
#          Job 6: Agile Software Engineer downloaded!
#          Job 7: Data Engineer downloaded!
#          Job 8: Service Delivery Manager downloaded!
#          Job 9: Webbutvecklare downloaded!
#          Job 10: Business Analyst downloaded!
#          Job 11: Senior Project Manager downloaded!
#          Job 12: Testare/Testledare till Sundsvall downloaded!
# Company 32: IBM
#          No jobs found for IBM
# Company 33: Amazon
#          Job 1: Manager of Cloud Operations downloaded!
#          Job 2: Instructional Designer downloaded!
# Company 34: Google
#          Job 1: Marketing & Social Media Manager downloaded!
# Company 35: Microsoft
#          No jobs found for Microsoft
#
# Total 791 jobs downloaded!
