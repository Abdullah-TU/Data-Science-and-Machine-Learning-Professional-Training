# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:
    
    # Define the two lists to concatenate
    DataScience = ['Data Science', 'Big data', 'Machine learning','ML', 'Data mining', 'Artificial intelligence', 'AI', 'Predictive modeling',
               'Statistical analysis', 'Data visualization', 'Deep learning', 'Natural language processing', 'Business intelligence',
               'Data warehousing', 'Data management', 'Data cleaning', 'Feature engineering', 'Time series analysis', 'Text analytics',
               'Database', 'SQL', 'NoSQL', 'Neural networks', 'Regression analysis', 'Clustering', 'Dimensionality reduction',
               'Anomaly detection', 'Recommender systems', 'Data integration', 'Data governance']
    
    MachineLearning = ['Machine learning', 'Data preprocessing', 'Feature selection', 'Feature engineering', 'Data visualization',
                   'Model selection', 'Hyperparameter tuning', 'Cross-validation', 'Ensemble methods', 'Neural networks', 'Deep learning',
                   'Convolutional neural networks', 'Recurrent neural networks', 'Natural language processing', 'Computer vision',
                   'Reinforcement learning', 'Unsupervised learning', 'Clustering', 'Dimensionality reduction', 'Bayesian methods',
                   'Time series analysis', 'Random forest', 'Gradient boosting', 'Support vector machines', 'Decision trees', 'Regression analysis']

    # Concatenate the two lists
    keywords = DataScience + MachineLearning
    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %% [markdown]
# ## Scrappigng data for Netherlands

# %%
country_name= "Netherlands"
geoId="102890719"
companies =['Booking.com', 'ASML',  'NXP Semiconductors',  'Coolblue', 'Exact','Deloitte', 'Capgemini', 'IBM', 'Amazon', 'Google', 'Microsoft', 'Uber', 'Xccelerated | Part of Xebia','Agoda', 'Qualcomm', 'Eindhoven University of Technology', 'ABN AMRO Bank N.V.', 'Kadaster', 'Cooder', 'Barrington James', 'Harnham', 'Creative Fabrica', 'University of Amsterdam', 'Lely', 'TELUS International AI Data Solutions', 'StarApple', 'Albert Heijn', 'TELUS International', 'Delft University of Technology', 'Orange Quarter']

print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("DS_jobs_netherlands.json")
# Out:
# Country:  Netherlands
#
# Company 1: Booking.com
#          Job 1: Instructional Designer downloaded!
#          Job 2: Director of Engineering DMLP downloaded!
#          Job 3: Principal Software Engineer - Marketing Tech downloaded!
#          Job 4: Jr. Compliance Operations Analyst downloaded!
#          Job 5: Financial Analyst downloaded!
#          Job 6: Instructional Designer downloaded!
#          Job 7: Principal Software Engineer - Marketing Tech downloaded!
# Company 2: ASML
#          Job 1: Senior Financial Controller downloaded!
#          Job 2: Talent & Learning Sector Lead downloaded!
#          Job 3: Strategic Sourcing Project Manager downloaded!
#          Job 4: Senior Finance Controller downloaded!
#          Job 5: Talent & Learning Manager – HR NL & EU downloaded!
#          Job 6: Senior Financial Controller – Financial Services – General accounting downloaded!
#          Job 7: Senior Business Program Manager downloaded!
#          Job 8: Talent Acquisition Team Lead downloaded!
#          Job 9: Logistics Supplier Manager downloaded!
#          Job 10: Supply Chain (Sr.) Project Coordinator downloaded!
#          Job 11: Customer Quality Manager downloaded!
#          Job 12: Group Manager Mechanical Engineering Manufacturing & Service Tooling downloaded!
#          Job 13: Medior Management Assistant downloaded!
#          Job 14: Senior Financial Controller - Sales downloaded!
#          Job 15: Senior Finance Business Partner downloaded!
#          Job 16: Talent & Learning Sector Lead downloaded!
#          Job 17: Strategic Sourcing Project Manager downloaded!
#          Job 18: Senior Finance Controller downloaded!
#          Job 19: Talent & Learning Manager – HR NL & EU downloaded!
#          Job 20: Senior Financial Controller – Financial Services – General accounting downloaded!
#          Job 21: Senior Business Program Manager downloaded!
#          Job 22: Supply Chain NPI Project Manager downloaded!
#          Job 23: Talent Acquisition Team Lead downloaded!
#          Job 24: Logistics Supplier Manager downloaded!
#          Job 25: Group Manager Mechanical Engineering Manufacturing & Service Tooling downloaded!
#          Job 26: Medior Management Assistant downloaded!
#          Job 27: Senior Financial Controller - Sales downloaded!
#          Job 28: Senior Finance Business Partner downloaded!
#          Job 29: Supplier Operations Deployment Manager downloaded!
#          Job 30: Senior PMO DUV Improvement Lead downloaded!
#          Job 31: Senior Business Program Manager downloaded!
#          Job 32: Supply Chain NPI Project Manager downloaded!
#          Job 33: Talent Acquisition Team Lead downloaded!
#          Job 34: Logistics Supplier Manager downloaded!
#          Job 35: Product Owner Supply Planning downloaded!
#          Job 36: Senior PMO DUV Improvement Lead downloaded!
#          Job 37: Quality Manager D&E ASML Delft downloaded!
#          Job 38: (Senior) project manager - business intelligence & analytics downloaded!
#          Job 39: Senior Financial Controller downloaded!
#          Job 40: Talent & Learning Sector Lead downloaded!
#          Job 41: Strategic Sourcing Project Manager downloaded!
#          Job 42: Senior Finance Controller downloaded!
#          Job 43: Customer Quality Manager downloaded!
#          Job 44: Group Manager Mechanical Engineering Manufacturing & Service Tooling downloaded!
#          Job 45: Medior Management Assistant downloaded!
#          Job 46: Senior Financial Controller - Sales downloaded!
#          Job 47: Senior Finance Business Partner downloaded!
#          Job 48: Senior PMO DUV Improvement Lead downloaded!
#          Job 49: Proto Engineer EUV 24x7 at Imec (Belgium) downloaded!
#          Job 50: Space Planner downloaded!
#          Job 51: Quality Manager D&E ASML Delft downloaded!
#          Job 52: Talent & Learning Sector Lead downloaded!
#          Job 53: Strategic Sourcing Project Manager downloaded!
#          Job 54: Senior Finance Controller downloaded!
#          Job 55: Talent & Learning Manager – HR NL & EU downloaded!
#          Job 56: Senior Financial Controller – Financial Services – General accounting downloaded!
#          Job 57: Senior Business Program Manager downloaded!
#          Job 58: HR Business Partner downloaded!
#          Job 59: Product Owner Supply Planning downloaded!
#          Job 60: Supplier Operations Deployment Manager downloaded!
#          Job 61: Senior PMO DUV Improvement Lead downloaded!
#          Job 62: Strategic Sourcing Project Manager downloaded!
#          Job 63: Senior Finance Controller downloaded!
#          Job 64: Supply Chain (Sr.) Project Coordinator downloaded!
#          Job 65: Senior PMO DUV Improvement Lead downloaded!
#          Job 66: Proto Engineer EUV 24x7 at Imec (Belgium) downloaded!
#          Job 67: Talent & Learning Sector Lead downloaded!
#          Job 68: Senior Finance Controller downloaded!
#          Job 69: Talent & Learning Manager – HR NL & EU downloaded!
#          Job 70: Logistics Supplier Manager downloaded!
#          Job 71: HR Business Partner downloaded!
#          Job 72: Product Owner Supply Planning downloaded!
#          Job 73: Program Management Officer (PMO) - process improvements downloaded!
#          Job 74: Group Manager Mechanical Engineering Manufacturing & Service Tooling downloaded!
#          Job 75: Senior Financial Controller - Sales downloaded!
#          Job 76: Supplier Operations Deployment Manager downloaded!
#          Job 77: Senior Financial Controller downloaded!
#          Job 78: Talent & Learning Sector Lead downloaded!
#          Job 79: Strategic Sourcing Project Manager downloaded!
#          Job 80: Senior Finance Controller downloaded!
#          Job 81: Senior Financial Controller – Financial Services – General accounting downloaded!
#          Job 82: Logistics Supplier Manager downloaded!
#          Job 83: Quality Manager D&E ASML Delft downloaded!
#          Job 84: Supply Chain (Sr.) Project Coordinator downloaded!
#          Job 85: Talent & Learning Sector Lead downloaded!
#          Job 86: Strategic Sourcing Project Manager downloaded!
#          Job 87: Senior Financial Controller – Financial Services – General accounting downloaded!
#          Job 88: Senior Financial Controller - Sales downloaded!
# Company 3: NXP Semiconductors
#          Job 1: Equipment Engineer Wet Process downloaded!
#          Job 2: Software Engineer DFT Diagnosis Tool/Flow Development downloaded!
#          Job 3: Test Equipment Engineer downloaded!
#          Job 4: Equipment Engineer Wet Process downloaded!
#          Job 5: Software Engineer DFT Diagnosis Tool/Flow Development downloaded!
#          Job 6: PhD in AI-driven calibration of Analog-to-Digital converters downloaded!
#          Job 7: PostDoc in Machine Learning for Integrated Circuit design flow downloaded!
#          Job 8: Equipment Engineer Wet Process downloaded!
#          Job 9: Software Engineer DFT Diagnosis Tool/Flow Development downloaded!
#          Job 10: Test Equipment Engineer downloaded!
#          Job 11: Equipment Engineer Wet Process downloaded!
#          Job 12: PhD in AI-driven calibration of Analog-to-Digital converters downloaded!
#          Job 13: PostDoc in Machine Learning for Integrated Circuit design flow downloaded!
#          Job 14: Software Engineer DFT Diagnosis Tool/Flow Development downloaded!
# Company 4: Coolblue
#          Job 1: Front-End React Developer downloaded!
#          Job 2: Front-End Developer Coolblue Energy downloaded!
#          Job 3: Medior C# Developer downloaded!
#          Job 4: Stage Data Analyse downloaded!
#          Job 5: Front-End React Developer downloaded!
#          Job 6: Junior Analist Operations downloaded!
#          Job 7: Stage Data Analyse downloaded!
#          Job 8: Medior Analist A/B Testing downloaded!
#          Job 9: Junior Front-End Developer downloaded!
#          Job 10: Front-End React Developer downloaded!
#          Job 11: Front-End React Developer downloaded!
#          Job 12: Junior Analist Operations downloaded!
#          Job 13: Front-End Developer Coolblue Energy downloaded!
#          Job 14: Front-End Developer Coolblue Energy downloaded!
#          Job 15: Junior Analist Operations downloaded!
#          Job 16: Junior Front-End Developer downloaded!
# Company 5: Exact
#          Job 1: Vacature (Junior) Functioneel Beheerder downloaded!
#          Job 2: Data & Risk Analist downloaded!
# Company 6: Deloitte
#          Job 1: Consultant Data & Responsible Insight downloaded!
#          Job 2: Consultant Data Engineering and Analytics downloaded!
#          Job 3: Consultant Data & Responsible Insight downloaded!
# Company 7: Capgemini
#          No jobs found for Capgemini
# Company 8: IBM
#          Job 1: Tax Accounting & Compliance Analyst downloaded!
# Company 9: Amazon
#          No jobs found for Amazon
# Company 10: Google
#          Job 1: Student Researcher, 2023 downloaded!
#          Job 2: Student Researcher, 2023 downloaded!
#          Job 3: Junior Back-end Developer downloaded!
#          Job 4: Data Analist downloaded!
#          Job 5: Student Researcher, 2023 downloaded!
#          Job 6: Junior Back-end Developer downloaded!
#          Job 7: Student Researcher, 2023 downloaded!
#          Job 8: Data Analist downloaded!
#          Job 9: Student Researcher, 2023 downloaded!
#          Job 10: Junior Back-end Developer downloaded!
#          Job 11: Student Researcher, 2023 downloaded!
#          Job 12: Junior Back-end Developer downloaded!
#          Job 13: Student Researcher, 2023 downloaded!
#          Job 14: Front End Engineer downloaded!
#          Job 15: CRM Internship downloaded!
#          Job 16: Senior Frontend Engineer downloaded!
#          Job 17: Junior Back-end Developer downloaded!
#          Job 18: Student Researcher, 2023 downloaded!
#          Job 19: Student Researcher, 2023 downloaded!
#          Job 20: Student Researcher, 2023 downloaded!
#          Job 21: Junior Back-end Developer downloaded!
# Company 11: Microsoft
#          No jobs found for Microsoft
# Company 12: Uber
#          Job 1: Staff Software Engineer, Backend - ML Platform | Amsterdam downloaded!
# Company 13: Xccelerated | Part of Xebia
#          No jobs found for Xccelerated | Part of Xebia
# Company 14: Agoda
#          Job 1: Analytical roles – Analyst/ Senior Analyst/ Associate Manager (Bangkok Based, Relocation Provided) downloaded!
# Company 15: Qualcomm
#          No jobs found for Qualcomm
# Company 16: Eindhoven University of Technology
#          Job 1: Assistant Professor Information Visualisation downloaded!
# Company 17: ABN AMRO Bank N.V.
#          Job 1: Data Modelling Internship downloaded!
# Company 18: Kadaster
#          Job 1: Stagiair data science - Kadaster & EuroSDR downloaded!
#          Job 2: Stagiair data science - Kadaster & EuroSDR downloaded!
#          Job 3: Stagiair data science - Kadaster & EuroSDR downloaded!
#          Job 4: Stagiair data science - Kadaster & EuroSDR downloaded!
#          Job 5: Stagiair data science - Kadaster & EuroSDR downloaded!
#          Job 6: Stagiair data science - Kadaster & EuroSDR downloaded!
# Company 19: Cooder
#          Job 1: Python / all-round web developer | Leukeleu downloaded!
#          Job 2: .NET Developer | Amazing Bits downloaded!
# Company 20: Barrington James
#          No jobs found for Barrington James
# Company 21: Harnham
#          Job 1: BI Developer downloaded!
#          Job 2: Senior Marketing Effectiveness Analyst downloaded!
#          Job 3: NLP Data Scientist downloaded!
#          Job 4: Lead Data Scientist - Hybrid downloaded!
#          Job 5: BI Developer downloaded!
#          Job 6: Data Scientist - NLP downloaded!
#          Job 7: Machine Learning Engineer - Recommendations! downloaded!
# Company 22: Creative Fabrica
#          Job 1: Lead Software Engineer - Mobile downloaded!
#          Job 2: Senior Software Engineer - Community Tools downloaded!
# Company 23: University of Amsterdam
#          Job 1: Student Affairs Officer downloaded!
#          Job 2: Student Affairs Officer downloaded!
#          Job 3: Onderzoeksmedewerker Sociale Psychologie downloaded!
#          Job 4: Onderwijsdirecteur Graduate School Social Sciences (Interne vacature) downloaded!
#          Job 5: 2 Assistant Lecturers for the Master's Programme Information Studies FNWI downloaded!
#          Job 6: Onderwijsdirecteur Graduate School Social Sciences (Interne vacature) downloaded!
#          Job 7: Onderzoeksmedewerker Sociale Psychologie downloaded!
#          Job 8: Assistant Professor in Human Geography, Planning and/or International Development Studies: the Human downloaded!
# Company 24: Lely
#          No jobs found for Lely
# Company 25: TELUS International AI Data Solutions
#          Job 1: Online Data Analyst downloaded!
#          Job 2: Online Data Analyst downloaded!
#          Job 3: Online Data Analyst downloaded!
#          Job 4: Online Data Analyst downloaded!
#          Job 5: Online Data Analyst downloaded!
#          Job 6: Online Data Analyst downloaded!
# Company 26: StarApple
#          No jobs found for StarApple
# Company 27: Albert Heijn
#          Job 1: Stagiair(e) WO Innovation & Business Development downloaded!
#          Job 2: Stagiair(e) WO Innovation & Business Development downloaded!
#          Job 3: Senior Engineer (PL/SQL, Java, Microservices)- Retail & Business Services Platform downloaded!
#          Job 4: Data Analyst PPM downloaded!
# Company 28: TELUS International
#          No jobs found for TELUS International
# Company 29: Delft University of Technology
#          No jobs found for Delft University of Technology
# Company 30: Orange Quarter
#          No jobs found for Orange Quarter
#
# Total 191 jobs downloaded!

# %% [markdown]
# # full stalk netherlands

# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:    

    # Concatenate the two lists
    keywords = ['Front-end development', 'HTML', 'CSS', 'JavaScript', 'React', 'Angular', 'Vue.js', 'Bootstrap', 'jQuery', 'responsive design',      'Back-end development', 'Node.js', 'Python', 'Ruby', 'PHP', 'Java', '.NET', 'SQL', 'NoSQL', 'RESTful APIs', 'web servers',      'Database management', 'MySQL', 'PostgreSQL', 'MongoDB', 'Redis', 'Cassandra', 'Oracle', 'SQL Server',      'DevOps', 'AWS', 'Azure', 'Google Cloud', 'Docker', 'Kubernetes', 'Git', 'Jenkins', 'Travis CI', 'CircleCI', 'monitoring and logging tools',      'Project management', 'Agile', 'Scrum', 'Kanban', 'JIRA', 'Trello', 'Asana', 'project planning', 'team collaboration', 'communication skills']

    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %%
country_name= "Netherlands"
geoId="102890719"
companies =['NAVARA', 'Buro5 Recruitment', 'StarApple', 'CGI Nederland', 'Good Company', 'typ', 'StackBird', 'DEXTER', ' Sparkling People', 'Cooder', 'TNO', 'Ministerie van Defensie', 'ALTEN Nederland', 'Kadaster', 'Opus Recruitment Solutions', 'Capgemini', 'IBM', 'Amazon', 'Google', 'Microsoft', 'Agoda', 'Qualcomm', 'Eindhoven University of Technology', 'Trinamics', 'Cegeka', 'Barrington James', 'CodeGuild', 'Creative Fabrica', 'Centric', 'Leap29', 'Picnic Technologies', 'Albert Heijn', 'Frontend Professionals', 'Orange Quarter', 'HiQ', 'Darwin Recruitment']


print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("FS_jobs_netherlands.json")
# Out:
# Country:  Netherlands
#
# Company 1: NAVARA
#          Job 1: Data Scientist | Navara Enterprise Analytics B.V. downloaded!
#          Job 2: Data Science Consultant | Navara downloaded!
#          Job 3: Data Engineer | Navara Enterprise Analytics B.V. downloaded!
#          Job 4: Mobile Engineer | Navara downloaded!
#          Job 5: Junior Frontend Developer in Rotterdam downloaded!
#          Job 6: React Native Developer | Navara downloaded!
#          Job 7: Full-stack Software Engineer downloaded!
#          Job 8: Senior Full-stack Software Engineer downloaded!
#          Job 9: Medior Frontend Developer in Rotterdam downloaded!
#          Job 10: Senior Frontend Developer in Rotterdam downloaded!
#          Job 11: Senior Tech Lead in Rotterdam downloaded!
#          Job 12: Data Science Consultant | Navara downloaded!
#          Job 13: Mobile Engineer | Navara downloaded!
#          Job 14: Junior Frontend Developer in Rotterdam downloaded!
#          Job 15: Frontend Engineer | Navara downloaded!
#          Job 16: Data Engineering Consultant | Navara downloaded!
#          Job 17: React Native Developer | Navara downloaded!
#          Job 18: Full-stack Software Engineer downloaded!
#          Job 19: Senior Full-stack Software Engineer downloaded!
#          Job 20: Medior Frontend Developer in Rotterdam downloaded!
#          Job 21: Senior Frontend Developer in Rotterdam downloaded!
#          Job 22: Senior Tech Lead in Rotterdam downloaded!
#          Job 23: Data Scientist | Navara Enterprise Analytics B.V. downloaded!
#          Job 24: Data Engineer | Navara Enterprise Analytics B.V. downloaded!
#          Job 25: Mobile Engineer | Navara downloaded!
#          Job 26: Junior Frontend Developer in Rotterdam downloaded!
#          Job 27: Frontend Engineer | Navara downloaded!
#          Job 28: Data Engineering Consultant | Navara downloaded!
#          Job 29: Fullstack .NET Engineer | Navara downloaded!
#          Job 30: Back-end Developer downloaded!
#          Job 31: Senior Tech Lead in Rotterdam downloaded!
#          Job 32: Mobile Engineer | Navara downloaded!
#          Job 33: Fullstack .NET Engineer | Navara downloaded!
#          Job 34: Senior Frontend Developer in Rotterdam downloaded!
#          Job 35: Senior Full-stack Software Engineer downloaded!
#          Job 36: Front-end Developer downloaded!
#          Job 37: Frontend Engineer | Navara downloaded!
#          Job 38: Fullstack Java Engineer | Navara downloaded!
#          Job 39: Data Scientist | Navara Enterprise Analytics B.V. downloaded!
#          Job 40: Data Science Consultant | Navara downloaded!
#          Job 41: Mobile Engineer | Navara downloaded!
#          Job 42: Junior Frontend Developer in Rotterdam downloaded!
#          Job 43: Frontend Engineer | Navara downloaded!
#          Job 44: React Native Developer | Navara downloaded!
#          Job 45: Full-stack Software Engineer downloaded!
#          Job 46: Data Scientist | Navara Enterprise Analytics B.V. downloaded!
#          Job 47: Data Science Consultant | Navara downloaded!
#          Job 48: Data Engineer | Navara Enterprise Analytics B.V. downloaded!
#          Job 49: Mobile Engineer | Navara downloaded!
#          Job 50: Junior Frontend Developer in Rotterdam downloaded!
#          Job 51: Data Engineering Consultant | Navara downloaded!
#          Job 52: Front-end Developer downloaded!
#          Job 53: Back-end Developer downloaded!
#          Job 54: Full-stack Software Engineer downloaded!
#          Job 55: Senior Full-stack Software Engineer downloaded!
#          Job 56: Medior Frontend Developer in Rotterdam downloaded!
#          Job 57: Senior Frontend Developer in Rotterdam downloaded!
# Company 2: Buro5 Recruitment
#          Job 1: Data Analyst | Valcon NL downloaded!
#          Job 2: Back-End Developer | ANWB downloaded!
#          Job 3: Senior Back-end Developer | ANWB downloaded!
#          Job 4: Java developer | Gaiyo downloaded!
#          Job 5: Data Scientist | Brink downloaded!
#          Job 6: Data Scientist | Interfood Group downloaded!
#          Job 7: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 8: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 9: Business Analist | Meant2B downloaded!
#          Job 10: Informatie Consultant | NORISK Visionair downloaded!
#          Job 11: QA Engineer | Gaiyo downloaded!
#          Job 12: Data Analist | Scamander Solutions downloaded!
#          Job 13: Data Scientist | Interfood Group downloaded!
#          Job 14: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 15: Data Analyst | Valcon NL downloaded!
#          Job 16: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 17: Back-End Developer | ANWB downloaded!
#          Job 18: Business Intelligence Specialist | CleanLease downloaded!
#          Job 19: Junior .NET ontwikkelaar | Amsterdam | Betabit downloaded!
#          Job 20: Senior Back-end Developer | ANWB downloaded!
#          Job 21: Java developer | Gaiyo downloaded!
#          Job 22: Business Analist | Meant2B downloaded!
#          Job 23: Data Scientist / Analist | Infiniot downloaded!
#          Job 24: Informatie Consultant | NORISK Visionair downloaded!
#          Job 25: Netwerk Engineer | ANWB downloaded!
#          Job 26: Data Analist | Scamander Solutions downloaded!
#          Job 27: Data Scientist | Interfood Group downloaded!
#          Job 28: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 29: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 30: Data Analyst | Valcon NL downloaded!
#          Job 31: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 32: Back-End Developer | ANWB downloaded!
#          Job 33: Support engineer | IT Performance Group downloaded!
#          Job 34: Business Intelligence Specialist | CleanLease downloaded!
#          Job 35: Senior Back-end Developer | ANWB downloaded!
#          Job 36: Data Analyst | Valcon NL downloaded!
#          Job 37: Back-End Developer | ANWB downloaded!
#          Job 38: Senior Back-end Developer | ANWB downloaded!
#          Job 39: Java developer | Gaiyo downloaded!
#          Job 40: QA Engineer | Gaiyo downloaded!
#          Job 41: Data Scientist | Brink downloaded!
#          Job 42: Business Analist | Meant2B downloaded!
#          Job 43: .NET Software Engineer | Freshminds downloaded!
#          Job 44: Data Scientist | Interfood Group downloaded!
#          Job 45: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 46: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 47: Business Analist | Meant2B downloaded!
#          Job 48: Data Scientist / Analist | Infiniot downloaded!
#          Job 49: Informatie Consultant | NORISK Visionair downloaded!
#          Job 50: Netwerk Engineer | ANWB downloaded!
#          Job 51: Data Analist | Scamander Solutions downloaded!
#          Job 52: Data Scientist | Interfood Group downloaded!
#          Job 53: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 54: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 55: Data Analyst | Valcon NL downloaded!
#          Job 56: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 57: Back-End Developer | ANWB downloaded!
#          Job 58: Support engineer | IT Performance Group downloaded!
#          Job 59: Business Intelligence Specialist | CleanLease downloaded!
#          Job 60: Senior Back-end Developer | ANWB downloaded!
#          Job 61: Data Analyst | Valcon NL downloaded!
#          Job 62: Back-End Developer | ANWB downloaded!
#          Job 63: Senior Back-end Developer | ANWB downloaded!
#          Job 64: Java developer | Gaiyo downloaded!
#          Job 65: QA Engineer | Gaiyo downloaded!
#          Job 66: Data Scientist | Brink downloaded!
#          Job 67: Business Analist | Meant2B downloaded!
#          Job 68: .NET Software Engineer | Freshminds downloaded!
#          Job 69: Data Scientist | Interfood Group downloaded!
#          Job 70: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 71: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 72: Business Analist | Meant2B downloaded!
#          Job 73: Data Scientist / Analist | Infiniot downloaded!
#          Job 74: Informatie Consultant | NORISK Visionair downloaded!
#          Job 75: Netwerk Engineer | ANWB downloaded!
#          Job 76: Data Analist | Scamander Solutions downloaded!
#          Job 77: Data Scientist | Interfood Group downloaded!
#          Job 78: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 79: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 80: Data Analyst | Valcon NL downloaded!
#          Job 81: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 82: Back-End Developer | ANWB downloaded!
#          Job 83: Support engineer | IT Performance Group downloaded!
#          Job 84: Business Intelligence Specialist | CleanLease downloaded!
#          Job 85: Senior Back-end Developer | ANWB downloaded!
#          Job 86: Business Analist | Meant2B downloaded!
#          Job 87: Informatie Consultant | NORISK Visionair downloaded!
#          Job 88: QA Engineer | Gaiyo downloaded!
#          Job 89: Data Analist | Scamander Solutions downloaded!
#          Job 90: Data Scientist | Interfood Group downloaded!
#          Job 91: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 92: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 93: Data Analyst | Valcon NL downloaded!
#          Job 94: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 95: Back-End Developer | ANWB downloaded!
#          Job 96: Business Intelligence Specialist | CleanLease downloaded!
#          Job 97: Junior .NET ontwikkelaar | Amsterdam | Betabit downloaded!
#          Job 98: Senior Back-end Developer | ANWB downloaded!
#          Job 99: Java developer | Gaiyo downloaded!
#          Job 100: Data Scientist | Brink downloaded!
#          Job 101: Business Analist | Meant2B downloaded!
#          Job 102: Data Scientist / Analist | Infiniot downloaded!
#          Job 103: Informatie Consultant | NORISK Visionair downloaded!
#          Job 104: Netwerk Engineer | ANWB downloaded!
#          Job 105: Data Analist | Scamander Solutions downloaded!
#          Job 106: Data Scientist | Interfood Group downloaded!
#          Job 107: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 108: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 109: Data Analyst | Valcon NL downloaded!
#          Job 110: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 111: Back-End Developer | ANWB downloaded!
#          Job 112: Support engineer | IT Performance Group downloaded!
#          Job 113: Business Intelligence Specialist | CleanLease downloaded!
#          Job 114: Senior Back-end Developer | ANWB downloaded!
#          Job 115: Data Engineer | Bincy downloaded!
#          Job 116: Frontend Developer | Waste Vision downloaded!
#          Job 117: Full Stack JavaScript Developer | ANWB downloaded!
#          Job 118: IT-support medewerker | Skrepr downloaded!
#          Job 119: Senior Data Analyst | Bright Cape downloaded!
#          Job 120: Medior .NET developer | Amsterdam | Betabit downloaded!
#          Job 121: Power BI Specialist | DataSense downloaded!
#          Job 122: Business analist Regulatory reporting | Riviq B.V. downloaded!
#          Job 123: Android native app developer | Brand New Day downloaded!
#          Job 124: Cloud en Modern Workplace Engineer | Didacticum downloaded!
#          Job 125: NET Developer (C#, SQL, ASP.NET) | VWE Automotive downloaded!
#          Job 126: Data Engineer / BI | Riviq B.V. downloaded!
#          Job 127: Data Software Engineer | Freshminds downloaded!
#          Job 128: Business Analist | Meant2B downloaded!
#          Job 129: Data Scientist / Analist | Infiniot downloaded!
#          Job 130: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 131: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 132: Data Analyst | Valcon NL downloaded!
#          Job 133: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 134: Back-End Developer | ANWB downloaded!
#          Job 135: Support engineer | IT Performance Group downloaded!
#          Job 136: Business Intelligence Specialist | CleanLease downloaded!
#          Job 137: Senior Back-end Developer | ANWB downloaded!
#          Job 138: Business Analist | Meant2B downloaded!
#          Job 139: Data Scientist / Analist | Infiniot downloaded!
#          Job 140: Informatie Consultant | NORISK Visionair downloaded!
#          Job 141: Netwerk Engineer | ANWB downloaded!
#          Job 142: Data Analist | Scamander Solutions downloaded!
#          Job 143: Data Scientist | Interfood Group downloaded!
#          Job 144: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 145: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 146: Data Analyst | Valcon NL downloaded!
#          Job 147: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 148: Back-End Developer | ANWB downloaded!
#          Job 149: Support engineer | IT Performance Group downloaded!
#          Job 150: Business Intelligence Specialist | CleanLease downloaded!
#          Job 151: Senior Back-end Developer | ANWB downloaded!
#          Job 152: Business Analist | Meant2B downloaded!
#          Job 153: Data Scientist / Analist | Infiniot downloaded!
#          Job 154: Informatie Consultant | NORISK Visionair downloaded!
#          Job 155: Netwerk Engineer | ANWB downloaded!
#          Job 156: Data Analist | Scamander Solutions downloaded!
#          Job 157: Data Scientist | Interfood Group downloaded!
#          Job 158: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 159: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 160: Data Analyst | Valcon NL downloaded!
#          Job 161: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 162: Back-End Developer | ANWB downloaded!
#          Job 163: Support engineer | IT Performance Group downloaded!
#          Job 164: Business Intelligence Specialist | CleanLease downloaded!
#          Job 165: Data Analyst | Valcon NL downloaded!
#          Job 166: Back-End Developer | ANWB downloaded!
#          Job 167: Senior Back-end Developer | ANWB downloaded!
#          Job 168: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 169: Data Scientist | Interfood Group downloaded!
#          Job 170: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 171: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 172: Senior Back-end Developer | ANWB downloaded!
#          Job 173: Data Analyst | Valcon NL downloaded!
#          Job 174: Back-End Developer | ANWB downloaded!
#          Job 175: Java developer | Gaiyo downloaded!
#          Job 176: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 177: Data Analyst | Valcon NL downloaded!
#          Job 178: Back-End Developer | ANWB downloaded!
#          Job 179: Senior Back-end Developer | ANWB downloaded!
#          Job 180: Java developer | Gaiyo downloaded!
#          Job 181: QA Engineer | Gaiyo downloaded!
#          Job 182: Data Scientist | Brink downloaded!
#          Job 183: Business Analist | Meant2B downloaded!
#          Job 184: .NET Software Engineer | Freshminds downloaded!
#          Job 185: Data Scientist | Interfood Group downloaded!
#          Job 186: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 187: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 188: Business Analist | Meant2B downloaded!
#          Job 189: Informatie Consultant | NORISK Visionair downloaded!
#          Job 190: QA Engineer | Gaiyo downloaded!
#          Job 191: Data Analist | Scamander Solutions downloaded!
#          Job 192: Data Scientist | Interfood Group downloaded!
#          Job 193: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 194: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 195: Data Analyst | Valcon NL downloaded!
#          Job 196: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 197: Back-End Developer | ANWB downloaded!
#          Job 198: Business Intelligence Specialist | CleanLease downloaded!
#          Job 199: Junior .NET ontwikkelaar | Amsterdam | Betabit downloaded!
#          Job 200: Senior Back-end Developer | ANWB downloaded!
#          Job 201: Java developer | Gaiyo downloaded!
#          Job 202: Data Scientist | Brink downloaded!
#          Job 203: Business Analist | Meant2B downloaded!
#          Job 204: Data Scientist / Analist | Infiniot downloaded!
#          Job 205: Informatie Consultant | NORISK Visionair downloaded!
#          Job 206: Netwerk Engineer | ANWB downloaded!
#          Job 207: Data Analist | Scamander Solutions downloaded!
#          Job 208: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 209: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 210: Data Analyst | Valcon NL downloaded!
#          Job 211: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 212: Back-End Developer | ANWB downloaded!
#          Job 213: Support engineer | IT Performance Group downloaded!
#          Job 214: Business Analist | Meant2B downloaded!
#          Job 215: Data Scientist / Analist | Infiniot downloaded!
#          Job 216: Informatie Consultant | NORISK Visionair downloaded!
#          Job 217: Netwerk Engineer | ANWB downloaded!
#          Job 218: Data Analist | Scamander Solutions downloaded!
#          Job 219: Data Scientist | Interfood Group downloaded!
#          Job 220: Junior C# Front-end Developer | PalmSens downloaded!
#          Job 221: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 222: Data Analyst | Valcon NL downloaded!
#          Job 223: Junior Backend Developer C# .NET | Gamebasics downloaded!
#          Job 224: Back-End Developer | ANWB downloaded!
#          Job 225: Support engineer | IT Performance Group downloaded!
#          Job 226: Business Intelligence Specialist | CleanLease downloaded!
#          Job 227: Senior Back-end Developer | ANWB downloaded!
#          Job 228: Business Analist | Meant2B downloaded!
#          Job 229: Data Scientist / Analist | Infiniot downloaded!
#          Job 230: Informatie Consultant | NORISK Visionair downloaded!
#          Job 231: Netwerk Engineer | ANWB downloaded!
#          Job 232: Data Analist | Scamander Solutions downloaded!
#          Job 233: Junior .NET developer | Rotterdam | Betabit downloaded!
#          Job 234: Data Analyst | Valcon NL downloaded!
#          Job 235: Support engineer | IT Performance Group downloaded!
#          Job 236: Business Intelligence Specialist | CleanLease downloaded!
# Company 3: StarApple
#          Job 1: Junior Software Developer downloaded!
#          Job 2: Junior Front end developer downloaded!
#          Job 3: Junior developer downloaded!
#          Job 4: Data Scientist downloaded!
#          Job 5: Junior Developer downloaded!
#          Job 6: Junior Data Scientist downloaded!
#          Job 7: Software Engineer Traineeship downloaded!
#          Job 8: Junior/Medior Software Developer downloaded!
#          Job 9: Junior Software Developer downloaded!
#          Job 10: Junior Software Developer downloaded!
#          Job 11: Junior Front end developer downloaded!
#          Job 12: Junior developer downloaded!
#          Job 13: Traineeship Front-end developer (WO, 0 tot 3 jaar ervaring) downloaded!
#          Job 14: data scientist downloaded!
#          Job 15: Data Scientist downloaded!
#          Job 16: Junior Developer downloaded!
#          Job 17: Junior Data Scientist downloaded!
#          Job 18: Data Analyst - Google (junior/medior) downloaded!
#          Job 19: Junior Software Developer downloaded!
#          Job 20: Junior Data Scientist downloaded!
#          Job 21: Junior Developer downloaded!
#          Job 22: Data Analyst - Google (junior/medior) downloaded!
#          Job 23: Machine Learning Specialist downloaded!
#          Job 24: Data-analist downloaded!
#          Job 25: data scientist downloaded!
#          Job 26: Data Analyst downloaded!
#          Job 27: Software Developer downloaded!
#          Job 28: Data Scientist downloaded!
#          Job 29: Tester downloaded!
#          Job 30: Junior full stack developer downloaded!
#          Job 31: Traineeship Front-end developer (WO, 0 tot 3 jaar ervaring) downloaded!
#          Job 32: data scientist downloaded!
#          Job 33: Data Scientist downloaded!
#          Job 34: Junior Developer downloaded!
#          Job 35: Data Analyst - Google (junior/medior) downloaded!
#          Job 36: Junior Front end developer downloaded!
#          Job 37: Software Engineer Traineeship downloaded!
#          Job 38: Junior/Medior Software Developer downloaded!
#          Job 39: Junior Data Scientist downloaded!
#          Job 40: Junior+ Front end developer downloaded!
#          Job 41: Junior front-end developer downloaded!
#          Job 42: (Junior) Business Analist downloaded!
#          Job 43: Junior Software Developer downloaded!
#          Job 44: Junior Software Developer downloaded!
#          Job 45: Junior Front-end developer downloaded!
#          Job 46: Junior Front end developer downloaded!
#          Job 47: Junior developer downloaded!
#          Job 48: Junior full stack developer downloaded!
#          Job 49: Data Scientist downloaded!
#          Job 50: data scientist downloaded!
#          Job 51: Junior Data Scientist downloaded!
#          Job 52: Junior Developer downloaded!
#          Job 53: Traineeship Front-end developer (WO, 0 tot 3 jaar ervaring) downloaded!
#          Job 54: Frontend developer (junior+/ medior) downloaded!
#          Job 55: Junior Software Developer downloaded!
#          Job 56: Junior Data Scientist downloaded!
#          Job 57: Junior Developer downloaded!
#          Job 58: Data Analyst - Google (junior/medior) downloaded!
#          Job 59: Data Scientist downloaded!
#          Job 60: Machine Learning Specialist downloaded!
#          Job 61: Data Analyst downloaded!
#          Job 62: Software Developer downloaded!
#          Job 63: Data Scientist downloaded!
#          Job 64: Tester downloaded!
#          Job 65: Marketing Data Analist downloaded!
#          Job 66: Data Analyst downloaded!
#          Job 67: Data-analist downloaded!
#          Job 68: data scientist downloaded!
#          Job 69: Python-ontwikkelaar downloaded!
#          Job 70: Junior Data Scientist downloaded!
#          Job 71: Junior+ Front end developer downloaded!
#          Job 72: Junior Front-end developer downloaded!
#          Job 73: Junior Front end developer downloaded!
#          Job 74: Junior developer downloaded!
#          Job 75: Junior full stack developer downloaded!
#          Job 76: Data Analyst - Google (junior/medior) downloaded!
#          Job 77: Junior front-end developer downloaded!
#          Job 78: Junior Software Developer downloaded!
#          Job 79: Junior Software Developer downloaded!
#          Job 80: Junior Front-end developer downloaded!
#          Job 81: Junior developer downloaded!
#          Job 82: Junior Data Scientist downloaded!
#          Job 83: Python Developer downloaded!
#          Job 84: Junior Front end developer downloaded!
#          Job 85: Front-endontwikkelaar downloaded!
#          Job 86: Junior PHP ontwikkelaar downloaded!
#          Job 87: Junior Data Scientist downloaded!
#          Job 88: Junior Developer downloaded!
#          Job 89: data scientist downloaded!
#          Job 90: Data Analyst - Google (junior/medior) downloaded!
#          Job 91: Tester downloaded!
#          Job 92: Marketing Data Analist downloaded!
#          Job 93: Data Analyst downloaded!
#          Job 94: Junior Data Scientist downloaded!
#          Job 95: Data Analyst - Google (junior/medior) downloaded!
#          Job 96: Data Scientist downloaded!
#          Job 97: Marketing Data Analist downloaded!
#          Job 98: Data Analyst downloaded!
#          Job 99: Junior Software Developer downloaded!
#          Job 100: Junior Data Scientist downloaded!
#          Job 101: Marketing Data Analist downloaded!
#          Job 102: Data Analyst downloaded!
#          Job 103: Data-analist downloaded!
#          Job 104: data scientist downloaded!
#          Job 105: Junior full stack developer downloaded!
#          Job 106: Traineeship Front-end developer (WO, 0 tot 3 jaar ervaring) downloaded!
#          Job 107: data scientist downloaded!
#          Job 108: Data Scientist downloaded!
#          Job 109: Junior Developer downloaded!
#          Job 110: Junior Data Scientist downloaded!
# Company 4: CGI Nederland
#          Job 1: Project Manager downloaded!
#          Job 2: Data Analytics Consultant - Banking downloaded!
#          Job 3: Agile Project Management Ondersteuner (PMO) downloaded!
#          Job 4: Business Analist - Banking downloaded!
#          Job 5: Senior IT Project Manager downloaded!
# Company 5: Good Company
#          No jobs found for Good Company
# Company 6: typ
#          No jobs found for typ
# Company 7: StackBird
#          No jobs found for StackBird
# Company 8: DEXTER
#          No jobs found for DEXTER
# Company 9:  Sparkling People
#          Job 1: Immigration Associate downloaded!
#          Job 2: Immigration Associate downloaded!
#          Job 3: Immigration Associate downloaded!
#          Job 4: Immigration Associate downloaded!
# Company 10: Cooder
#          No jobs found for Cooder
# Company 11: TNO
#          Job 1: Internship | Recurrent deep learning applied to radar data downloaded!
#          Job 2: Internship | Photothermal design for light-driven sustainable chemical processes downloaded!
#          Job 3: Internship | Metallic nanowires for improved photo/electrocatalysis downloaded!
#          Job 4: Internship | Recurrent deep learning applied to radar data downloaded!
#          Job 5: Project Manager Thin Film Electronics | Eindhoven downloaded!
# Company 12: Ministerie van Defensie
#          No jobs found for Ministerie van Defensie
# Company 13: ALTEN Nederland
#          Job 1: Robotics Engineer downloaded!
#          Job 2: Fullstack Software Engineer downloaded!
#          Job 3: Medior Software Test Engineer downloaded!
#          Job 4: Embedded Software Engineer downloaded!
#          Job 5: Senior Java Developer downloaded!
#          Job 6: Senior Software Engineer downloaded!
#          Job 7: Robotics Engineer downloaded!
#          Job 8: Medior Software Test Engineer downloaded!
#          Job 9: Senior Software Engineer downloaded!
#          Job 10: Test Engineer | Alten downloaded!
#          Job 11: Fullstack Software Engineer downloaded!
#          Job 12: Medior Software Test Engineer downloaded!
#          Job 13: Robotics Engineer downloaded!
#          Job 14: Embedded Software Engineer downloaded!
#          Job 15: Senior Java Developer downloaded!
#          Job 16: Senior Software Engineer downloaded!
#          Job 17: Test Engineer | Alten downloaded!
#          Job 18: Robotics Engineer downloaded!
#          Job 19: Fullstack Software Engineer downloaded!
#          Job 20: Medior Software Test Engineer downloaded!
#          Job 21: Embedded Software Engineer downloaded!
#          Job 22: Senior Java Developer downloaded!
#          Job 23: Senior Software Engineer downloaded!
#          Job 24: Test Engineer | Alten downloaded!
#          Job 25: Robotics Engineer downloaded!
#          Job 26: Medior Software Test Engineer downloaded!
#          Job 27: Embedded Software Engineer downloaded!
#          Job 28: Senior Java Developer downloaded!
#          Job 29: Senior Software Engineer downloaded!
#          Job 30: Test Engineer | Alten downloaded!
#          Job 31: Robotics Engineer downloaded!
#          Job 32: Fullstack Software Engineer downloaded!
#          Job 33: Medior Software Test Engineer downloaded!
#          Job 34: Senior Java Developer downloaded!
#          Job 35: Senior Software Engineer downloaded!
#          Job 36: Test Engineer | Alten downloaded!
#          Job 37: Robotics Engineer downloaded!
#          Job 38: Medior Software Test Engineer downloaded!
#          Job 39: Test Engineer | Alten downloaded!
#          Job 40: Robotics Engineer downloaded!
#          Job 41: Senior Java Developer downloaded!
#          Job 42: Test Engineer | Alten downloaded!
#          Job 43: Robotics Engineer downloaded!
#          Job 44: Fullstack Software Engineer downloaded!
#          Job 45: Medior Software Test Engineer downloaded!
#          Job 46: Senior Java Developer downloaded!
#          Job 47: Senior Software Engineer downloaded!
#          Job 48: Test Engineer | Alten downloaded!
#          Job 49: Robotics Engineer downloaded!
#          Job 50: Medior Software Test Engineer downloaded!
#          Job 51: Embedded Software Engineer downloaded!
#          Job 52: Senior Java Developer downloaded!
#          Job 53: Senior Software Engineer downloaded!
#          Job 54: Test Engineer | Alten downloaded!
#          Job 55: Robotics Engineer downloaded!
#          Job 56: Fullstack Software Engineer downloaded!
#          Job 57: Medior Software Test Engineer downloaded!
#          Job 58: Test Engineer | Alten downloaded!
#          Job 59: Fullstack Software Engineer downloaded!
#          Job 60: Medior Software Test Engineer downloaded!
#          Job 61: Embedded Software Engineer downloaded!
# Company 14: Kadaster
#          Job 1: Risk & Compliance Officer (IT) downloaded!
#          Job 2: Java Developer downloaded!
#          Job 3: Risk & Compliance Officer (IT) downloaded!
#          Job 4: Java Developer downloaded!
#          Job 5: Java Software engineer downloaded!
#          Job 6: Java Developer (Junior/Medior) downloaded!
#          Job 7: Java Developer (Junior/Medior) downloaded!
#          Job 8: Java Developer (Junior/Medior) downloaded!
#          Job 9: Java Developer (Junior/Medior) downloaded!
#          Job 10: Java Developer (Junior/Medior) downloaded!
#          Job 11: Java Developer (Junior/Medior) downloaded!
#          Job 12: Risk & Compliance Officer (IT) downloaded!
#          Job 13: Java Developer (Junior/Medior) downloaded!
#          Job 14: Java Software engineer downloaded!
#          Job 15: Medior/Senior Software Engineer (Java) downloaded!
#          Job 16: Java Developer (Junior/Medior) downloaded!
#          Job 17: Java Developer (Junior/Medior) downloaded!
#          Job 18: Java Developer (Junior/Medior) downloaded!
#          Job 19: Java Developer (Junior/Medior) downloaded!
#          Job 20: Java Developer (Junior/Medior) downloaded!
#          Job 21: Java Developer (Junior/Medior) downloaded!
#          Job 22: Java Developer (Junior/Medior) downloaded!
#          Job 23: Java Developer downloaded!
#          Job 24: Java Developer (Junior/Medior) downloaded!
#          Job 25: Java Developer (Junior/Medior) downloaded!
#          Job 26: Java Developer (Junior/Medior) downloaded!
#          Job 27: Java Developer (Junior/Medior) downloaded!
#          Job 28: Java Developer (Junior/Medior) downloaded!
#          Job 29: Java Developer (Junior/Medior) downloaded!
#          Job 30: Java Developer (Junior/Medior) downloaded!
#          Job 31: Java Developer (Junior/Medior) downloaded!
#          Job 32: Java Developer (Junior/Medior) downloaded!
#          Job 33: Java Developer downloaded!
#          Job 34: Java Developer (Junior/Medior) downloaded!
#          Job 35: Java Developer (Junior/Medior) downloaded!
#          Job 36: Java Developer (Junior/Medior) downloaded!
#          Job 37: Java Developer (Junior/Medior) downloaded!
#          Job 38: Java Developer (Junior/Medior) downloaded!
#          Job 39: Java Developer (Junior/Medior) downloaded!
#          Job 40: Java Developer (Junior/Medior) downloaded!
#          Job 41: Java Developer (Junior/Medior) downloaded!
#          Job 42: Java Developer (Junior/Medior) downloaded!
#          Job 43: Java Developer downloaded!
#          Job 44: Java Developer (Junior/Medior) downloaded!
#          Job 45: Java Developer (Junior/Medior) downloaded!
#          Job 46: Java Developer (Junior/Medior) downloaded!
#          Job 47: Java Developer (Junior/Medior) downloaded!
#          Job 48: Java Developer (Junior/Medior) downloaded!
#          Job 49: Java Developer (Junior/Medior) downloaded!
#          Job 50: Java Developer (Junior/Medior) downloaded!
#          Job 51: Java Developer (Junior/Medior) downloaded!
#          Job 52: Java Developer downloaded!
#          Job 53: Java Developer (Junior/Medior) downloaded!
# Company 15: Opus Recruitment Solutions
#          Job 1: Recruitment Consultant - Technology downloaded!
#          Job 2: Managing Consultant downloaded!
#          Job 3: Node.JS Developer - Up to €135,000 per year! downloaded!
#          Job 4: Back End Developer downloaded!
#          Job 5: Back End Developer downloaded!
#          Job 6: Freelance Fullstack Javascript Developer downloaded!
#          Job 7: Recruitment Consultant - Technology downloaded!
#          Job 8: Python Developer - eCommerce downloaded!
#          Job 9: .NET Developer downloaded!
#          Job 10: Medior React Developer | Amsterdam downloaded!
#          Job 11: Senior Front-End Developer (React) - Amsterdam (Hybrid) downloaded!
#          Job 12: Python Developer - Utrecht (Hybrid) downloaded!
# Company 16: Capgemini
#          No jobs found for Capgemini
# Company 17: IBM
#          No jobs found for IBM
# Company 18: Amazon
#          Job 1: Data Scientist downloaded!
#          Job 2: Global Head of Procurement downloaded!
#          Job 3: E-commerce Specialist downloaded!
#          Job 4: Global Head of Procurement downloaded!
#          Job 5: International Business Director (Amsterdam) downloaded!
#          Job 6: Data Scientist downloaded!
#          Job 7: Global Head of Procurement downloaded!
#          Job 8: Scrum Master downloaded!
#          Job 9: Marketing Analytics & Operations Intern downloaded!
#          Job 10: E-commerce Specialist downloaded!
#          Job 11: Global Head of Procurement downloaded!
#          Job 12: E-commerce Specialist downloaded!
#          Job 13: Director, International Business (Amsterdam) downloaded!
#          Job 14: International Business Director (Amsterdam) downloaded!
#          Job 15: Data Scientist downloaded!
# Company 19: Google
#          Job 1: Student Researcher, 2023 downloaded!
#          Job 2: Junior Back-end Developer downloaded!
#          Job 3: Application Manager downloaded!
#          Job 4: Student Researcher, 2023 downloaded!
#          Job 5: Director, International Business (Amsterdam) downloaded!
#          Job 6: Application Manager downloaded!
#          Job 7: Marketing and Events Internships (Sustainability) downloaded!
#          Job 8: Director, International Business (Amsterdam) downloaded!
#          Job 9: International Business Director (Amsterdam) downloaded!
#          Job 10: Data Analist downloaded!
#          Job 11: Junior Back-end Developer downloaded!
#          Job 12: Digital Marketing downloaded!
#          Job 13: Student Researcher, 2023 downloaded!
#          Job 14: Marketing and Events Internships (Sustainability) downloaded!
#          Job 15: Procurement and Planning Analyst downloaded!
#          Job 16: Marketing and Events Internships (Sustainability) downloaded!
#          Job 17: Digital Marketing downloaded!
# Company 20: Microsoft
#          Job 1: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 2: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 3: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 4: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 5: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 6: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 7: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 8: Junior Brand Manager downloaded!
#          Job 9: Commercial Business Controller downloaded!
#          Job 10: Junior Brand Manager downloaded!
#          Job 11: Data analist downloaded!
#          Job 12: Software Development Traineeship downloaded!
#          Job 13: Business Analyst downloaded!
#          Job 14: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 15: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 16: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 17: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 18: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 19: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 20: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 21: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 22: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 23: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 24: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 25: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 26: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 27: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 28: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
#          Job 29: Senior Program Manager - Capacity, Supply Chain & Provisioning organization downloaded!
# Company 21: Agoda
#          Job 1: Analytical roles – Analyst/ Senior Analyst/ Associate Manager (Bangkok Based, Relocation Provided) downloaded!
#          Job 2: Business Analyst (Bangkok Based, Relocation Provided) downloaded!
#          Job 3: Senior Analyst/Lead, Corporate Strategy (Bangkok Based) downloaded!
#          Job 4: Product Designer – Consumer Facing (Bangkok-based, Relocation Provided) downloaded!
#          Job 5: Director Marketing Analytics (Bangkok Based, Relocation Provided) downloaded!
#          Job 6: Customer Insights Analyst (Bangkok Based, Relocation Provided) downloaded!
#          Job 7: Senior Marketing Manager, Social Media Team (Bangkok-based, relocation provided) downloaded!
#          Job 8: Manager, Strategic Partnerships – Strategy and Analytics (Bangkok based, relocation provided) downloaded!
#          Job 9: Business Analyst (Bangkok Based, Relocation Provided) downloaded!
#          Job 10: Analyst (Bangkok Based, Relocation Provided) downloaded!
#          Job 11: People Analytics Manager (Bangkok based, relocation provided) downloaded!
#          Job 12: Customer Insights Analyst (Bangkok Based, Relocation Provided) downloaded!
# Company 22: Qualcomm
#          No jobs found for Qualcomm
# Company 23: Eindhoven University of Technology
#          Job 1: Vice-Dean Department Mathematics & Computer Science downloaded!
#          Job 2: (Junior) postdoc in the area of deep learning and deep generative modeling downloaded!
#          Job 3: Lecturer Architectural Urban Design and Engineering (AUDE) (0,8 FTE) downloaded!
# Company 24: Trinamics
#          Job 1: Open Application Starters & Juniors downloaded!
#          Job 2: Open Application, Fresh Graduates, Starters, First Job downloaded!
#          Job 3: Junior Production Engineer downloaded!
#          Job 4: Software Engineer (Python and C++) downloaded!
#          Job 5: Software Engineer (Python and C++) downloaded!
#          Job 6: Open Application Starters & Juniors downloaded!
#          Job 7: Agile Coach downloaded!
#          Job 8: Robotics / Mechatronic Engineer with experience in precision mechanics + MATLAB downloaded!
#          Job 9: Sr project manager - Portfolio management downloaded!
# Company 25: Cegeka
#          Job 1: Scrum Master downloaded!
#          Job 2: Traineeship Business & IT downloaded!
#          Job 3: Junior Software Architect downloaded!
#          Job 4: Junior Digital Workplace Consultant downloaded!
#          Job 5: Office 365 Consultant downloaded!
#          Job 6: Scrum Master downloaded!
#          Job 7: Product Owner downloaded!
#          Job 8: Java Developer downloaded!
#          Job 9: Junior Digital Workplace Consultant downloaded!
#          Job 10: Office 365 Consultant downloaded!
#          Job 11: Project Manager ERP downloaded!
#          Job 12: Office 365 Consultant downloaded!
#          Job 13: Traineeship Data downloaded!
#          Job 14: Traineeship Business & IT downloaded!
#          Job 15: Junior IT Proces Consultant downloaded!
#          Job 16: Agile Coach downloaded!
#          Job 17: Junior Software Architect downloaded!
#          Job 18: Agile Projectmanager downloaded!
#          Job 19: Scrum Master downloaded!
#          Job 20: Product Owner downloaded!
#          Job 21: Java Developer downloaded!
#          Job 22: Junior Digital Workplace Consultant downloaded!
#          Job 23: Office 365 Consultant downloaded!
#          Job 24: Project Manager ERP downloaded!
#          Job 25: Office 365 Consultant downloaded!
#          Job 26: Agile Coach downloaded!
#          Job 27: Junior Software Architect downloaded!
#          Job 28: Productivity Consultant downloaded!
#          Job 29: Agile Projectmanager downloaded!
#          Job 30: Product Owner downloaded!
#          Job 31: Java Developer downloaded!
#          Job 32: Junior Digital Workplace Consultant downloaded!
#          Job 33: Office 365 Consultant downloaded!
#          Job 34: Project Manager ERP downloaded!
#          Job 35: Office 365 Consultant downloaded!
#          Job 36: Traineeship Business & IT downloaded!
#          Job 37: Junior IT Proces Consultant downloaded!
#          Job 38: Agile Coach downloaded!
#          Job 39: Junior Software Architect downloaded!
#          Job 40: Productivity Consultant downloaded!
#          Job 41: Agile Projectmanager downloaded!
#          Job 42: Junior Digital Workplace Consultant downloaded!
#          Job 43: Office 365 Consultant downloaded!
#          Job 44: Scrum Master downloaded!
#          Job 45: Product Owner downloaded!
#          Job 46: Java Developer downloaded!
#          Job 47: Junior Digital Workplace Consultant downloaded!
#          Job 48: Office 365 Consultant downloaded!
#          Job 49: Project Manager ERP downloaded!
#          Job 50: Office 365 Consultant downloaded!
#          Job 51: Traineeship Data downloaded!
#          Job 52: Traineeship Business & IT downloaded!
#          Job 53: Junior IT Proces Consultant downloaded!
#          Job 54: Agile Coach downloaded!
#          Job 55: Junior Software Architect downloaded!
#          Job 56: Agile Projectmanager downloaded!
#          Job 57: Junior IT Proces Consultant downloaded!
#          Job 58: Office 365 Consultant downloaded!
#          Job 59: Office 365 Consultant downloaded!
#          Job 60: Project Manager ERP downloaded!
# Company 26: Barrington James
#          Job 1: NLP Data Scientist downloaded!
# Company 27: CodeGuild
#          Job 1: Java Developer | eHealth downloaded!
#          Job 2: Senior Java Developer downloaded!
#          Job 3: Java Developer | €70.000 downloaded!
#          Job 4: Senior Java Developer downloaded!
#          Job 5: Java Developer | Salaris €77.800 + bonus downloaded!
#          Job 6: Senior Backend Engineer | €115.000 + 100% Remote downloaded!
#          Job 7: Senior Backend Node.JS Engineer | €85.000 + Shares downloaded!
#          Job 8: Junior DevOps Engineer | Salaris tot € 55.000 + 6K bonus downloaded!
#          Job 9: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 10: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 11: Senior Java Software Engineer | Greenfield downloaded!
#          Job 12: Medior Full-Stack JavaScript Developer | €75.000 + 10% bonus + remote options downloaded!
#          Job 13: Senior Backend Engineer Golang | €91.000 + Bonus downloaded!
#          Job 14: Senior Java Software engineer Big Data | €80.000 +10% bonus downloaded!
#          Job 15: Java Developer | €70.000 downloaded!
#          Job 16: Senior Java Developer | €90,000 downloaded!
#          Job 17: Senior Full-Stack JavaScript Developer | €85.000 + 10% bonus + remote possibilities downloaded!
#          Job 18: Front end Developer | €78.000 obv 36 hours + bonus downloaded!
#          Job 19: Medior Java Developer| €70.000 downloaded!
#          Job 20: Java Developer | eHealth downloaded!
#          Job 21: Senior Backend Engineer Java/Kotlin downloaded!
#          Job 22: Senior Java Developer | Greenfield downloaded!
#          Job 23: Senior Java Developer downloaded!
#          Job 24: Senior Java Developer downloaded!
#          Job 25: Java Developer downloaded!
#          Job 26: Senior Backend Engineer | €115.000 + 100% Remote downloaded!
#          Job 27: Senior Backend Node.JS Engineer | €85.000 + Shares downloaded!
#          Job 28: Junior DevOps Engineer | Salaris tot € 55.000 + 6K bonus downloaded!
#          Job 29: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 30: Java Developer - AI Product leert Honderden Miljoenen Kinderen Leren! downloaded!
#          Job 31: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 32: Senior Java Software Engineer | Greenfield downloaded!
#          Job 33: Medior Full-Stack JavaScript Developer | €75.000 + 10% bonus + remote options downloaded!
#          Job 34: Senior Backend Engineer Golang | €90.000 + 100% remote + relocation package downloaded!
#          Job 35: Senior Backend Engineer Golang | €91.000 + Bonus downloaded!
#          Job 36: Senior Java Software engineer Big Data | €80.000 +10% bonus downloaded!
#          Job 37: Java Developer | €70.000 downloaded!
#          Job 38: Senior Java Developer | €90,000 downloaded!
#          Job 39: Senior Full-Stack JavaScript Developer | €85.000 + 10% bonus + remote possibilities downloaded!
#          Job 40: Front end Developer | €78.000 obv 36 hours + bonus downloaded!
#          Job 41: Medior Java Developer| €70.000 downloaded!
#          Job 42: Java Developer | eHealth downloaded!
#          Job 43: Senior Backend Engineer Java/Kotlin downloaded!
#          Job 44: Senior Java Developer | Greenfield downloaded!
#          Job 45: Senior Java Developer downloaded!
#          Job 46: Senior Java Developer downloaded!
#          Job 47: Java Developer downloaded!
#          Job 48: Java Developer | Salaris €77.800 + bonus downloaded!
#          Job 49: Senior Backend Engineer | €115.000 + 100% Remote downloaded!
#          Job 50: Senior Backend Node.JS Engineer | €85.000 + Shares downloaded!
#          Job 51: Junior DevOps Engineer | Salaris tot € 55.000 + 6K bonus downloaded!
#          Job 52: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 53: Java Developer - AI Product leert Honderden Miljoenen Kinderen Leren! downloaded!
#          Job 54: Senior Java Software Engineer | Tot € 125.000,- + aandelenopties + remote mogelijkheden downloaded!
#          Job 55: Senior Java Software Engineer | Greenfield downloaded!
#          Job 56: Medior Full-Stack JavaScript Developer | €75.000 + 10% bonus + remote options downloaded!
#          Job 57: Senior Backend Engineer Golang | €90.000 + 100% remote + relocation package downloaded!
#          Job 58: Senior Backend Engineer | €115.000 + 100% Remote downloaded!
#          Job 59: Senior Backend Engineer Golang | €91.000 + Bonus downloaded!
#          Job 60: Senior Java Software engineer Big Data | €80.000 +10% bonus downloaded!
#          Job 61: Java Developer | €70.000 downloaded!
#          Job 62: Senior Java Developer | €90,000 downloaded!
# ...
#          Job 13: Frontend Developer bij Stoffenmanager downloaded!
#          Job 14: Front-end Developer downloaded!
#          Job 15: Stagiair(e) Development downloaded!
#          Job 16: JavaScript Developer downloaded!
#          Job 17: Front-end Developer 32 uur, Heel downloaded!
#          Job 18: Junior Software Developer downloaded!
#          Job 19: Front-end Developer downloaded!
#          Job 20: Junior Software Engineer downloaded!
#          Job 21: Junior Web Developer downloaded!
#          Job 22: Frontend Developer downloaded!
#          Job 23: Junior Front-end Developer, Utrecht downloaded!
#          Job 24: Front-End Developer downloaded!
#          Job 25: Junior Support Web Developer downloaded!
#          Job 26: Software Engineer JS downloaded!
#          Job 27: Front-end Software Engineer downloaded!
#          Job 28: Front End Ontwikkelaar | React downloaded!
#          Job 29: Internship/stage - IT downloaded!
#          Job 30: Frontend Developer bij Stoffenmanager downloaded!
#          Job 31: Stagiair(e) Development downloaded!
#          Job 32: Front-end Developer downloaded!
#          Job 33: Junior Web Developer downloaded!
#          Job 34: Junior Support Web Developer downloaded!
#          Job 35: Junior Software Engineer Utrecht Max EUR50K downloaded!
#          Job 36: Javascript Developer downloaded!
#          Job 37: Junior Front-end Developer downloaded!
#          Job 38: Front-end Developer bij Picturae downloaded!
#          Job 39: Front-End Developer and Analyst downloaded!
#          Job 40: Front-end Developer downloaded!
#          Job 41: Frontend Developer downloaded!
#          Job 42: Junior Front-end Developer, Utrecht downloaded!
#          Job 43: Front-End Developer downloaded!
#          Job 44: Junior Support Web Developer downloaded!
#          Job 45: Junior Software Engineer Utrecht Max EUR50K downloaded!
#          Job 46: Front-End Developer and Analyst downloaded!
#          Job 47: Frontend Developer bij Stoffenmanager downloaded!
#          Job 48: Stagiair(e) Development downloaded!
#          Job 49: JavaScript Developer downloaded!
#          Job 50: Front-end Developer 32 uur, Heel downloaded!
#          Job 51: Junior Software Developer downloaded!
#          Job 52: Junior Robotics Engineer - YPPIT downloaded!
#          Job 53: Front-end Software Engineer downloaded!
#          Job 54: Internship/stage - IT downloaded!
#          Job 55: Javascript Developer downloaded!
#          Job 56: Junior Front-end Developer downloaded!
#          Job 57: Junior Robotics Engineer - YPPIT downloaded!
#          Job 58: Front-end Developer downloaded!
#          Job 59: Junior Web Developer downloaded!
#          Job 60: Frontend Developer downloaded!
#          Job 61: Frontend Developer downloaded!
#          Job 62: Junior Front-end Developer, Utrecht downloaded!
#          Job 63: Javascript Developer downloaded!
#          Job 64: Junior Front-end Developer downloaded!
#          Job 65: Front-end Developer bij Picturae downloaded!
#          Job 66: Frontend Developer bij Stoffenmanager downloaded!
#          Job 67: Stagiair(e) Development downloaded!
#          Job 68: Front-End Developer and Analyst downloaded!
#          Job 69: Front-end Developer downloaded!
#          Job 70: JavaScript Developer downloaded!
#          Job 71: Junior Web Developer downloaded!
#          Job 72: Frontend Developer downloaded!
#          Job 73: Frontend Developer downloaded!
#          Job 74: Junior Front-end Developer, Utrecht downloaded!
#          Job 75: Front-End Developer downloaded!
#          Job 76: Junior Support Web Developer downloaded!
#          Job 77: Junior Software Engineer Utrecht Max EUR50K downloaded!
#          Job 78: Software Engineer JS downloaded!
#          Job 79: Front-end Software Engineer downloaded!
#          Job 80: Junior Front-end Developer downloaded!
#          Job 81: Front-end Developer bij Picturae downloaded!
#          Job 82: Front-End Developer and Analyst downloaded!
#          Job 83: Frontend Developer bij Stoffenmanager downloaded!
#          Job 84: Front-end Developer downloaded!
#          Job 85: JavaScript Developer downloaded!
#          Job 86: Front-end Developer 32 uur, Heel downloaded!
#          Job 87: Junior Software Developer downloaded!
#          Job 88: Front-end Developer 32 uur, Heel downloaded!
#          Job 89: Junior IT Recruiter downloaded!
#          Job 90: Junior Software Developer downloaded!
#          Job 91: Full Stack Developer downloaded!
#          Job 92: Software Engineer JS downloaded!
#          Job 93: Fullstack Developer – Regio Utrecht downloaded!
#          Job 94: Fullstack (Node.js &Vue.js) Developer - EdTech - North Brabant downloaded!
#          Job 95: Senior Front End Developer downloaded!
#          Job 96: Frontend Developer filmindustrie downloaded!
#          Job 97: Front-End Developer | Deli Home Ivenza downloaded!
#          Job 98: Junior Web Developer downloaded!
#          Job 99: Junior Support Web Developer downloaded!
#          Job 100: Javascript Developer downloaded!
#          Job 101: Front-end Developer downloaded!
#          Job 102: JavaScript Developer downloaded!
#          Job 103: Junior Software Engineer downloaded!
# Company 34: Orange Quarter
#          Job 1: Head of Growth downloaded!
#          Job 2: Amsterdam, Permanent downloaded!
#          Job 3: Marketing Designer downloaded!
#          Job 4: Marketing Specialist downloaded!
#          Job 5: Marketing Specialist downloaded!
#          Job 6: Frontend Developer (React/ Typescript) downloaded!
#          Job 7: Amsterdam, Netherlands downloaded!
#          Job 8: Growth Marketer downloaded!
#          Job 9: Junior Javascript Developer downloaded!
#          Job 10: Senior Marketing Manager downloaded!
#          Job 11: Head of Growth downloaded!
#          Job 12: Amsterdam, Permanent downloaded!
#          Job 13: Marketing Designer downloaded!
#          Job 14: Marketing Specialist downloaded!
#          Job 15: Marketing Specialist downloaded!
#          Job 16: Frontend Developer (React/ Typescript) downloaded!
#          Job 17: Amsterdam, Netherlands downloaded!
#          Job 18: Head of Growth downloaded!
#          Job 19: Amsterdam, Permanent downloaded!
#          Job 20: Marketing Designer downloaded!
#          Job 21: Amsterdam, Netherlands downloaded!
#          Job 22: Growth Marketer downloaded!
#          Job 23: Junior Javascript Developer downloaded!
#          Job 24: Senior Marketing Manager downloaded!
#          Job 25: Head of Growth downloaded!
#          Job 26: Marketing Specialist downloaded!
#          Job 27: Marketing Specialist downloaded!
#          Job 28: Frontend Developer (React/ Typescript) downloaded!
#          Job 29: Amsterdam, Netherlands downloaded!
#          Job 30: Growth Marketer downloaded!
#          Job 31: Junior Javascript Developer downloaded!
#          Job 32: Senior Marketing Manager downloaded!
#          Job 33: Head of Growth downloaded!
#          Job 34: Amsterdam, Permanent downloaded!
#          Job 35: Marketing Designer downloaded!
#          Job 36: Marketing Specialist downloaded!
#          Job 37: Marketing Specialist downloaded!
#          Job 38: Frontend Developer (React/ Typescript) downloaded!
#          Job 39: Amsterdam, Netherlands downloaded!
#          Job 40: Growth Marketer downloaded!
#          Job 41: Junior Javascript Developer downloaded!
#          Job 42: Senior Marketing Manager downloaded!
#          Job 43: Head of Growth downloaded!
#          Job 44: Amsterdam, Permanent downloaded!
#          Job 45: Marketing Designer downloaded!
#          Job 46: Marketing Specialist downloaded!
#          Job 47: Marketing Specialist downloaded!
#          Job 48: Frontend Developer (React/ Typescript) downloaded!
#          Job 49: Amsterdam, Netherlands downloaded!
#          Job 50: Growth Marketer downloaded!
#          Job 51: Junior Javascript Developer downloaded!
#          Job 52: Head of Growth downloaded!
#          Job 53: Amsterdam, Permanent downloaded!
#          Job 54: Marketing Specialist downloaded!
#          Job 55: Marketing Specialist downloaded!
#          Job 56: Frontend Developer (React/ Typescript) downloaded!
#          Job 57: Growth Marketer downloaded!
#          Job 58: Junior Javascript Developer downloaded!
#          Job 59: Senior Marketing Manager downloaded!
#          Job 60: Head of Growth downloaded!
#          Job 61: Amsterdam, Permanent downloaded!
#          Job 62: Marketing Designer downloaded!
#          Job 63: Marketing Specialist downloaded!
#          Job 64: Growth Marketer downloaded!
#          Job 65: Junior Javascript Developer downloaded!
#          Job 66: Senior Marketing Manager downloaded!
#          Job 67: Head of Growth downloaded!
#          Job 68: Marketing Designer downloaded!
#          Job 69: Marketing Specialist downloaded!
#          Job 70: Marketing Specialist downloaded!
#          Job 71: Frontend Developer (React/ Typescript) downloaded!
#          Job 72: Amsterdam, Netherlands downloaded!
#          Job 73: Growth Marketer downloaded!
#          Job 74: Junior Javascript Developer downloaded!
# Company 35: HiQ
#          No jobs found for HiQ
# Company 36: Darwin Recruitment
#          Job 1: Business Analyst downloaded!
#          Job 2: Office 365 Workplace Specialist downloaded!
#          Job 3: Data analyst downloaded!
#          Job 4: Data quality analyst downloaded!
#          Job 5: System Administrator downloaded!
#          Job 6: System Administrator downloaded!
#          Job 7: IT Operations Specialist downloaded!
#          Job 8: Jr. Systeembeheerder downloaded!
#          Job 9: Jr. Systeembeheerder downloaded!
#          Job 10: Data modeler downloaded!
#          Job 11: Field Engineer downloaded!
#          Job 12: Operations Manager (Cloud) downloaded!
#          Job 13: Microsoft 365 Administrator downloaded!
#          Job 14: System Administrator downloaded!
#          Job 15: IAM Analyst downloaded!
#          Job 16: Atlassian Consultant downloaded!
#          Job 17: Cloud Operations Manager downloaded!
#          Job 18: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 19: Business Analyst downloaded!
#          Job 20: Office 365 Workplace Specialist downloaded!
#          Job 21: Sr. PMO (Portfolio Management) downloaded!
#          Job 22: Data analyst downloaded!
#          Job 23: Data quality analyst downloaded!
#          Job 24: System Administrator downloaded!
#          Job 25: QA Tester - Data Reports downloaded!
#          Job 26: System Administrator downloaded!
#          Job 27: Data modeler downloaded!
#          Job 28: Field Engineer downloaded!
#          Job 29: Operations Manager (Cloud) downloaded!
#          Job 30: Microsoft 365 Administrator downloaded!
#          Job 31: System Administrator downloaded!
#          Job 32: IAM Analyst downloaded!
#          Job 33: Atlassian Consultant downloaded!
#          Job 34: Cloud Operations Manager downloaded!
#          Job 35: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 36: Business Analyst downloaded!
#          Job 37: Data analyst downloaded!
#          Job 38: Sr. PMO (Portfolio Management) downloaded!
#          Job 39: QA Tester - Data Reports downloaded!
#          Job 40: BI Visualization Consultant - Power BI downloaded!
#          Job 41: Office 365 Workplace Specialist downloaded!
#          Job 42: Data quality analyst downloaded!
#          Job 43: Field Engineer downloaded!
#          Job 44: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 45: System Administrator downloaded!
#          Job 46: IT Service Manager downloaded!
#          Job 47: IT Project Manager downloaded!
#          Job 48: Linux Engineer downloaded!
#          Job 49: Linux Engineer downloaded!
#          Job 50: Business Analyst downloaded!
#          Job 51: Sr. PMO (Portfolio Management) downloaded!
#          Job 52: BI Visualization Consultant downloaded!
#          Job 53: QA Tester - Data Reports downloaded!
#          Job 54: Office 365 Workplace Specialist downloaded!
#          Job 55: IT Operations Specialist downloaded!
#          Job 56: Data quality analyst downloaded!
#          Job 57: Business Analyst downloaded!
#          Job 58: Office 365 Workplace Specialist downloaded!
#          Job 59: Data quality analyst downloaded!
#          Job 60: System Administrator downloaded!
#          Job 61: System Administrator downloaded!
#          Job 62: IT Operations Specialist downloaded!
#          Job 63: Jr. Systeembeheerder downloaded!
#          Job 64: Jr. Systeembeheerder downloaded!
#          Job 65: Operations Manager (Cloud) downloaded!
#          Job 66: Microsoft 365 Administrator downloaded!
#          Job 67: System Administrator downloaded!
#          Job 68: IAM Analyst downloaded!
#          Job 69: Atlassian Consultant downloaded!
#          Job 70: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 71: Business Analyst downloaded!
#          Job 72: Data analyst downloaded!
#          Job 73: Sr. PMO (Portfolio Management) downloaded!
#          Job 74: BI Visualization Consultant downloaded!
#          Job 75: QA Tester - Data Reports downloaded!
#          Job 76: BI Visualization Consultant - Power BI downloaded!
#          Job 77: Office 365 Workplace Specialist downloaded!
#          Job 78: IT Operations Specialist downloaded!
#          Job 79: Data quality analyst downloaded!
#          Job 80: Field Engineer downloaded!
#          Job 81: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 82: System Administrator downloaded!
#          Job 83: IT Service Manager downloaded!
#          Job 84: IT Project Manager downloaded!
#          Job 85: Linux Engineer downloaded!
#          Job 86: SCRUM Master downloaded!
#          Job 87: Linux Engineer downloaded!
#          Job 88: Sr. PMO (Portfolio Management) downloaded!
#          Job 89: BI Visualization Consultant downloaded!
#          Job 90: QA Tester - Data Reports downloaded!
#          Job 91: BI Visualization Consultant - Power BI downloaded!
#          Job 92: Office 365 Workplace Specialist downloaded!
#          Job 93: IT Operations Specialist downloaded!
#          Job 94: IT Service Manager downloaded!
#          Job 95: IT Project Manager downloaded!
#          Job 96: Linux Engineer downloaded!
#          Job 97: SCRUM Master downloaded!
#          Job 98: Linux Engineer downloaded!
#          Job 99: Business Analyst downloaded!
#          Job 100: Data analyst downloaded!
#          Job 101: QA Tester - Data Reports downloaded!
#          Job 102: BI Visualization Consultant - Power BI downloaded!
#          Job 103: Office 365 Workplace Specialist downloaded!
#          Job 104: IT Operations Specialist downloaded!
#          Job 105: Data quality analyst downloaded!
#          Job 106: Field Engineer downloaded!
#          Job 107: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 108: System Administrator downloaded!
#          Job 109: IT Service Manager downloaded!
#          Job 110: IT Project Manager downloaded!
#          Job 111: Linux Engineer downloaded!
#          Job 112: SCRUM Master downloaded!
#          Job 113: Linux Engineer downloaded!
#          Job 114: Business Analyst downloaded!
#          Job 115: Office 365 Workplace Specialist downloaded!
#          Job 116: Sr. PMO (Portfolio Management) downloaded!
#          Job 117: QA Tester - Data Reports downloaded!
#          Job 118: System Administrator downloaded!
#          Job 119: IT Operations Specialist downloaded!
#          Job 120: Jr. Systeembeheerder downloaded!
#          Job 121: Jr. Systeembeheerder downloaded!
#          Job 122: Data modeler downloaded!
#          Job 123: Field Engineer downloaded!
#          Job 124: Operations Manager (Cloud) downloaded!
#          Job 125: Microsoft 365 Administrator downloaded!
#          Job 126: IAM Analyst downloaded!
#          Job 127: Business Analyst downloaded!
#          Job 128: Data analyst downloaded!
#          Job 129: FullStack Dev. (React/NodeJs) Healthcare downloaded!
#          Job 130: Sr. PMO (Portfolio Management) downloaded!
#          Job 131: System Administrator downloaded!
#          Job 132: Atlassian Consultant downloaded!
#          Job 133: Cloud Operations Manager downloaded!
#
# Total 1187 jobs downloaded!
