# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:
    
    # Define the two lists to concatenate
    DataScience = ['Data Science', 'Big data', 'Machine learning','ML', 'Data mining', 'Artificial intelligence', 'AI', 'Predictive modeling',
               'Statistical analysis', 'Data visualization', 'Deep learning', 'Natural language processing', 'Business intelligence',
               'Data warehousing', 'Data management', 'Data cleaning', 'Feature engineering', 'Time series analysis', 'Text analytics',
               'Database', 'SQL', 'NoSQL', 'Neural networks', 'Regression analysis', 'Clustering', 'Dimensionality reduction',
               'Anomaly detection', 'Recommender systems', 'Data integration', 'Data governance']
    
    MachineLearning = ['Machine learning', 'Data preprocessing', 'Feature selection', 'Feature engineering', 'Data visualization',
                   'Model selection', 'Hyperparameter tuning', 'Cross-validation', 'Ensemble methods', 'Neural networks', 'Deep learning',
                   'Convolutional neural networks', 'Recurrent neural networks', 'Natural language processing', 'Computer vision',
                   'Reinforcement learning', 'Unsupervised learning', 'Clustering', 'Dimensionality reduction', 'Bayesian methods',
                   'Time series analysis', 'Random forest', 'Gradient boosting', 'Support vector machines', 'Decision trees', 'Regression analysis']

    # Concatenate the two lists
    keywords = DataScience + MachineLearning
    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %% [markdown]
# ### Scrappigng data for Finland

# %%
country_name= "Finland"
geoId="100456013"
companies=['Wolt', 'Nigel Frank International', 'Tietoevry', 'Silo AI', 'Solita', 'CGI', 'Wärtsilä', 'F-Secure', 'Neste', 'Huawei', 'Aiven', 'Unikie', 'Smartly.io', 'Nokia', 'Vaisala', 'Futurice', 'Valohai', 'ABB', 'VTT']

print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("DS_jobs_finland.json")

# %% [markdown]
# # full stalck Finland

# %%
import requests
from bs4 import BeautifulSoup
import json


class LinkedinScraper:    

    # Concatenate the two lists
    keywords = ['Front-end development', 'HTML', 'CSS', 'JavaScript', 'React', 'Angular', 'Vue.js', 'Bootstrap', 'jQuery', 'responsive design',      'Back-end development', 'Node.js', 'Python', 'Ruby', 'PHP', 'Java', '.NET', 'SQL', 'NoSQL', 'RESTful APIs', 'web servers',      'Database management', 'MySQL', 'PostgreSQL', 'MongoDB', 'Redis', 'Cassandra', 'Oracle', 'SQL Server',      'DevOps', 'AWS', 'Azure', 'Google Cloud', 'Docker', 'Kubernetes', 'Git', 'Jenkins', 'Travis CI', 'CircleCI', 'monitoring and logging tools',      'Project management', 'Agile', 'Scrum', 'Kanban', 'JIRA', 'Trello', 'Asana', 'project planning', 'team collaboration', 'communication skills']

    
    def __init__(self, country_name, geoId, companies):
        self.country_name = country_name
        self.geoId = geoId
        self.companies = companies
        self.search_url_pattern = 'https://www.linkedin.com/jobs/search/?currentJobId={}&distance=25&geoId={}&keywords={}&refresh=true&start={}'

    
    
    def scrape_jobs(self, output_file_path):
        start_index = 0
        jobs_per_page = 25
        total_jobs_downloaded = 0        
        
        
        # Iterate over each company and search for matching jobs
        with open(output_file_path, 'w', encoding='utf-8') as json_file:
            for i, company in enumerate(self.companies):
                print(f"Company {i+1}: {company}")
                jobs_downloaded = 0
                # Iterate until no matching jobs are found
                while True:
                    # Construct the search URL
                    search_url = self.search_url_pattern.format(start_index, self.geoId, company, start_index)

                    # Send a GET request to the search URL
                    response = requests.get(search_url)

                    # Parse the HTML content of the page using BeautifulSoup
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Find all the job posting URLs on the page
                    job_urls = [a['href'] for a in soup.find_all('a', href=True) if '/jobs/view/' in a['href']]

                    # If no matching jobs are found, break the loop
                    if len(job_urls) == 0:
                        break

                    # Iterate over each job URL and extract the job information
                    for job_url in job_urls:               

                        # Send a GET request to the job URL

                        response = requests.get(job_url)

                        # Parse the HTML content of the page using BeautifulSoup
                        soup = BeautifulSoup(response.content, 'html.parser')

                        # Find the job title and company name
                        title = soup.find('h1', class_='topcard__title')
                        if title is not None:
                            title = title.text.strip()
                        else:
                            continue
                        company_name = soup.find('a', class_='topcard__org-name-link')
                        if company_name is not None:
                            company_name = company_name.text.strip()
                        else:
                            continue

                        # Find the div tag that contains the job description
                        description_div = soup.find('div', class_='description__text')

                        if description_div is not None:
                            # Extract the job description text
                            job_description = description_div.get_text().strip()
                            job_description = job_description.replace('Show more', '').replace('Show less', '')

                            # Remove any extra spaces from the job description
                            job_description = ' '.join(job_description.split())


                            found_keywords = [keyword for keyword in self.keywords if keyword in job_description]                      

                            if found_keywords:
                                job_info = {
                                    'Country_name': self.country_name,
                                    'company_name': company_name,
                                    'keywords': found_keywords,
                                    'description': job_description 
                                } 
                                
                                with open(output_file_path, 'a', encoding='utf-8') as json_file:
                                    json.dump(job_info, json_file, ensure_ascii=False)
                                    json_file.write('\n')
                                
                                jobs_downloaded += 1
                                total_jobs_downloaded += 1                       
                        
                    
                                print(f"         Job {jobs_downloaded}: {title} downloaded!") 
                            
                
                if jobs_downloaded == 0:
                    print(f"         No jobs found for {company}")  
                            
                        
        print()
        print("Total {} jobs downloaded!".format(total_jobs_downloaded ))

# %%
country_name= "Finland"
geoId="100456013"
companies = ['Oliver Parks', 'Trimble Inc.', 'Knowit', 'Eficode', 'Wolt', 'Nigel Frank International', 'Tietoevry', 'Nortal', 'Silo AI', 'Solita', 'CGI', 'Accenture', 'Wärtsilä', 'F-Secure', 'Neste', 'Nordea', 'Aiven', 'Unikie', 'Smartly.io', 'Nokia', 'Vaisala', 'Futurice', 'Elisa', 'Taiste', 'AlphaSense', 'Gofore', 'Canonical', 'Vincit']

print("Country: ", country_name)
print()

scraper = LinkedinScraper(country_name, geoId, companies )
scraper.scrape_jobs("FS_jobs_finland.json")
# Out:
# Country:  Finland
#
# Company 1: Oliver Parks
#          Job 1: Data Specialist downloaded!
#          Job 2: Technical Lead downloaded!
#          Job 3: Fullstack developer downloaded!
#          Job 4: Fullstack developer downloaded!
#          Job 5: Fullstack developer downloaded!
#          Job 6: Cloud Architect downloaded!
#          Job 7: Software developer downloaded!
#          Job 8: Back End Developer downloaded!
#          Job 9: Software developer downloaded!
#          Job 10: Software developer downloaded!
#          Job 11: Java Developer downloaded!
#          Job 12: Hands-on Lead Architect role in Helsinki region downloaded!
#          Job 13: Data Specialist downloaded!
#          Job 14: Technical Lead downloaded!
#          Job 15: Fullstack developer downloaded!
#          Job 16: Cloud Architect downloaded!
#          Job 17: Software developer downloaded!
#          Job 18: Back End Developer downloaded!
#          Job 19: Software developer downloaded!
#          Job 20: Software developer downloaded!
#          Job 21: Software developer downloaded!
#          Job 22: DevOps Engineer downloaded!
#          Job 23: Software developer downloaded!
#          Job 24: Ohjelmisto- ja integraatiokehittäjä downloaded!
#          Job 25: Software developer downloaded!
#          Job 26: Software developer downloaded!
#          Job 27: Software developer downloaded!
#          Job 28: Software developer downloaded!
#          Job 29: Software developer downloaded!
#          Job 30: Data Specialist downloaded!
# Company 2: Trimble Inc.
#          Job 1: Delphi / .NET developer downloaded!
#          Job 2: Delphi / .NET developer downloaded!
#          Job 3: Delphi / .NET developer downloaded!
#          Job 4: Delphi / .NET developer downloaded!
#          Job 5: Full Stack Web Developer (Angular/Java) downloaded!
#          Job 6: Full Stack Web Developer (Angular/Java) downloaded!
#          Job 7: Full Stack Web Developer (Angular/Java) downloaded!
#          Job 8: Full Stack Web Developer (Angular/Java) downloaded!
# Company 3: Knowit
#          Job 1: Advisory Consultant downloaded!
#          Job 2: Cloud Architect / Specialist (Azure) downloaded!
#          Job 3: Cloud Architect / Specialist (Azure) downloaded!
#          Job 4: Test Manager downloaded!
#          Job 5: Cloud Architect / Specialist (AWS) downloaded!
#          Job 6: C++ -kehittäjä downloaded!
#          Job 7: C++ -kehittäjä downloaded!
#          Job 8: Full-stack -kehittäjä downloaded!
#          Job 9: Full-stack -kehittäjä downloaded!
#          Job 10: Full-stack -kehittäjä downloaded!
#          Job 11: Advisory Consultant downloaded!
#          Job 12: Quality Assurance Lead downloaded!
#          Job 13: Agile Master downloaded!
#          Job 14: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 15: Cloud Architect / Specialist (AWS) downloaded!
#          Job 16: Cloud Architect / Specialist (Azure) downloaded!
#          Job 17: Cloud Architect / Specialist (AWS) downloaded!
#          Job 18: C++ -kehittäjä downloaded!
#          Job 19: C++ -kehittäjä downloaded!
#          Job 20: Test Automation Specialist downloaded!
#          Job 21: Senior Back-end Developer (PHP, WordPress) downloaded!
#          Job 22: Performance Test Engineer downloaded!
#          Job 23: DevOps-asiantuntija downloaded!
#          Job 24: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 25: C++ -kehittäjä downloaded!
#          Job 26: Senior Analytics Engineer downloaded!
#          Job 27: Full-stack -kehittäjä downloaded!
#          Job 28: Full-stack -kehittäjä downloaded!
#          Job 29: Full-stack -kehittäjä downloaded!
#          Job 30: Advisory Consultant downloaded!
#          Job 31: Quality Assurance Lead downloaded!
#          Job 32: Agile Master downloaded!
#          Job 33: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 34: Cloud Architect / Specialist (AWS) downloaded!
#          Job 35: Cloud Architect / Specialist (Azure) downloaded!
#          Job 36: Cloud Architect / Specialist (Azure) downloaded!
#          Job 37: Test Manager downloaded!
#          Job 38: Cloud Architect / Specialist (AWS) downloaded!
#          Job 39: C++ -kehittäjä downloaded!
#          Job 40: C++ -kehittäjä downloaded!
#          Job 41: Test Automation Specialist downloaded!
#          Job 42: Senior Back-end Developer (PHP, WordPress) downloaded!
#          Job 43: Performance Test Engineer downloaded!
#          Job 44: DevOps-asiantuntija downloaded!
#          Job 45: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 46: C++ -kehittäjä downloaded!
#          Job 47: Senior Analytics Engineer downloaded!
#          Job 48: Full-stack -kehittäjä downloaded!
#          Job 49: Advisory Consultant downloaded!
#          Job 50: Quality Assurance Lead downloaded!
#          Job 51: Agile Master downloaded!
#          Job 52: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 53: Cloud Architect / Specialist (AWS) downloaded!
#          Job 54: Cloud Architect / Specialist (Azure) downloaded!
#          Job 55: Cloud Architect / Specialist (Azure) downloaded!
#          Job 56: Test Manager downloaded!
#          Job 57: Cloud Architect / Specialist (AWS) downloaded!
#          Job 58: Performance Test Engineer downloaded!
#          Job 59: DevOps-asiantuntija downloaded!
#          Job 60: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 61: C++ -kehittäjä downloaded!
#          Job 62: Senior Analytics Engineer downloaded!
#          Job 63: Ohjelmistokehittäjä (Clojure, React.js) downloaded!
#          Job 64: Full-stack -kehittäjä downloaded!
#          Job 65: Full-stack -kehittäjä downloaded!
#          Job 66: Full-stack -kehittäjä downloaded!
#          Job 67: Advisory Consultant downloaded!
#          Job 68: Quality Assurance Lead downloaded!
#          Job 69: Agile Master downloaded!
#          Job 70: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 71: Cloud Architect / Specialist (AWS) downloaded!
#          Job 72: Cloud Architect / Specialist (Azure) downloaded!
#          Job 73: Cloud Architect / Specialist (Azure) downloaded!
#          Job 74: Test Manager downloaded!
#          Job 75: Cloud Architect / Specialist (AWS) downloaded!
#          Job 76: Test Automation Specialist downloaded!
#          Job 77: C++ -kehittäjä downloaded!
#          Job 78: Senior Analytics Engineer downloaded!
#          Job 79: Ohjelmistokehittäjä (Clojure, React.js) downloaded!
#          Job 80: Full-stack -kehittäjä downloaded!
#          Job 81: Full-stack -kehittäjä downloaded!
#          Job 82: Full-stack -kehittäjä downloaded!
#          Job 83: Test Automation Specialist downloaded!
#          Job 84: Senior Back-end Developer (PHP, WordPress) downloaded!
#          Job 85: Performance Test Engineer downloaded!
#          Job 86: DevOps-asiantuntija downloaded!
#          Job 87: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 88: C++ -kehittäjä downloaded!
#          Job 89: Senior Analytics Engineer downloaded!
#          Job 90: Cloud Architect / Specialist (AWS) downloaded!
#          Job 91: C++ -kehittäjä downloaded!
#          Job 92: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 93: Ohjelmistokehittäjä (Clojure, React.js) downloaded!
#          Job 94: Full-stack -kehittäjä downloaded!
#          Job 95: Advisory Consultant downloaded!
#          Job 96: Quality Assurance Lead downloaded!
#          Job 97: Agile Master downloaded!
#          Job 98: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 99: Cloud Architect / Specialist (AWS) downloaded!
#          Job 100: Ohjelmistokehittäjä (Clojure, React.js) downloaded!
#          Job 101: Quality Assurance Lead downloaded!
#          Job 102: Full-stack -kehittäjä downloaded!
#          Job 103: Agile Master downloaded!
#          Job 104: C++ -kehittäjä downloaded!
#          Job 105: Cloud Architect / Specialist (Azure) downloaded!
#          Job 106: Performance Test Engineer downloaded!
#          Job 107: DevOps-asiantuntija downloaded!
#          Job 108: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 109: C++ -kehittäjä downloaded!
#          Job 110: Quality Assurance Lead downloaded!
#          Job 111: Cloud Architect / Specialist (AWS) downloaded!
#          Job 112: Test Automation Specialist downloaded!
#          Job 113: DevOps-asiantuntija downloaded!
#          Job 114: Full-stack -kehittäjä downloaded!
#          Job 115: Avoin hakemus, Knowit Solutions FLX downloaded!
#          Job 116: Cloud Architect / Specialist (AWS) downloaded!
#          Job 117: Cloud Architect / Specialist (Azure) downloaded!
#          Job 118: Cloud Architect / Specialist (Azure) downloaded!
#          Job 119: Test Manager downloaded!
#          Job 120: Test Automation Specialist downloaded!
#          Job 121: Senior Back-end Developer (PHP, WordPress) downloaded!
#          Job 122: Performance Test Engineer downloaded!
#          Job 123: C++ -kehittäjä downloaded!
#          Job 124: Senior Back-end Developer (.NET, Optimizely) downloaded!
#          Job 125: Ohjelmistokehittäjä (Clojure, React.js) downloaded!
#          Job 126: Full-stack -kehittäjä downloaded!
#          Job 127: Full-stack -kehittäjä downloaded!
#          Job 128: Full-stack -kehittäjä downloaded!
#          Job 129: Agile Master downloaded!
#          Job 130: Cloud Architect / Specialist (Azure) downloaded!
#          Job 131: C++ -kehittäjä downloaded!
#          Job 132: Cloud Architect / Specialist (AWS) downloaded!
#          Job 133: C++ -kehittäjä downloaded!
#          Job 134: Senior Analytics Engineer downloaded!
# Company 4: Eficode
#          Job 1: Tell us what you want to do at Eficode! downloaded!
#          Job 2: Software Architect downloaded!
#          Job 3: Atlassian DevOps Consultant downloaded!
#          Job 4: Tell us what you want to do at Eficode! downloaded!
#          Job 5: DevOps Consultant downloaded!
#          Job 6: Software Architect downloaded!
#          Job 7: Software Architect downloaded!
# Company 5: Wolt
#          Job 1: Data Science - Machine Learning Engineer downloaded!
#          Job 2: Senior Python Backend Engineer, Courier Group downloaded!
#          Job 3: Process Owner - Record to Report downloaded!
#          Job 4: Data Science - Machine Learning Engineer downloaded!
#          Job 5: Engineering Team Lead, Data Modelling downloaded!
#          Job 6: Engineering Team Lead, Data Governance Engineering downloaded!
#          Job 7: Pricing Strategy Analyst downloaded!
#          Job 8: AI Engineer - DevOps/MLOps downloaded!
#          Job 9: Process Owner - Record to Report downloaded!
#          Job 10: Pricing Strategy Analyst downloaded!
#          Job 11: Senior Python Engineer, Self-service / Context-aware Automation downloaded!
#          Job 12: Senior Backend (Python) Engineer, Payment Integrations downloaded!
#          Job 13: Senior Frontend Engineer, Merchant Group downloaded!
#          Job 14: Senior Python Backend Engineer, Courier Group downloaded!
#          Job 15: Process Owner - Record to Report downloaded!
#          Job 16: Senior Python Backend Engineer, Courier Group downloaded!
# Company 6: Nigel Frank International
#          No jobs found for Nigel Frank International
# Company 7: Tietoevry
#          No jobs found for Tietoevry
# Company 8: Nortal
#          No jobs found for Nortal
# Company 9: Silo AI
#          Job 1: Software Developer downloaded!
#          Job 2: AI Engineer, Large Language Models downloaded!
#          Job 3: Full Stack Software Developer downloaded!
#          Job 4: AI Scientist, Large Language Models downloaded!
#          Job 5: AI Engineer, Large Language Models downloaded!
#          Job 6: Full Stack Software Developer downloaded!
#          Job 7: AI Engineer - DevOps/MLOps downloaded!
#          Job 8: Software Developer downloaded!
#          Job 9: AI Scientist, Large Language Models downloaded!
#          Job 10: AI Scientist, Large Language Models downloaded!
#          Job 11: AI Engineer, Large Language Models downloaded!
# Company 10: Solita
#          No jobs found for Solita
# Company 11: CGI
#          Job 1: Full Stack Developer downloaded!
#          Job 2: Solution Architect downloaded!
#          Job 3: Senior Frontend Developer downloaded!
#          Job 4: SAS Developer, Financial Services downloaded!
#          Job 5: .NET-kehittäjä downloaded!
#          Job 6: Senior Backend Developer - Java, AWS downloaded!
#          Job 7: Ratkaisuarkkitehti, generatiivinen AI downloaded!
#          Job 8: Digital Channel Architect downloaded!
#          Job 9: Oracle IAM Consultant downloaded!
#          Job 10: Azure AD IDM Consultant downloaded!
#          Job 11: Technical Analyst/Production Support downloaded!
#          Job 12: Full Stack Developer downloaded!
#          Job 13: Project Manager, Financial Services downloaded!
#          Job 14: Solution Architect downloaded!
#          Job 15: Senior Frontend Developer downloaded!
#          Job 16: Azure Cloud Consultant downloaded!
#          Job 17: Software Architect downloaded!
#          Job 18: Lead-kehittäjä downloaded!
#          Job 19: SAS Developer, Financial Services downloaded!
#          Job 20: Digital Channel Architect downloaded!
#          Job 21: Oracle IAM Consultant downloaded!
#          Job 22: Azure AD IDM Consultant downloaded!
#          Job 23: Technical Analyst/Production Support downloaded!
#          Job 24: Full Stack Developer downloaded!
#          Job 25: Project Manager, Financial Services downloaded!
#          Job 26: Solution Architect downloaded!
#          Job 27: Software Architect downloaded!
#          Job 28: Principal Cyber Operations Champion downloaded!
#          Job 29: SAS Developer, Financial Services downloaded!
#          Job 30: .NET-kehittäjä downloaded!
#          Job 31: Senior Backend Developer - Java, AWS downloaded!
#          Job 32: Ratkaisuarkkitehti, generatiivinen AI downloaded!
#          Job 33: Digital Channel Architect downloaded!
#          Job 34: Oracle IAM Consultant downloaded!
#          Job 35: Azure AD IDM Consultant downloaded!
# Company 12: Accenture
#          Job 1: Cloud Data Engineer downloaded!
#          Job 2: Data Architect downloaded!
#          Job 3: Cloud Data Engineer downloaded!
#          Job 4: Data Architect downloaded!
#          Job 5: ServiceNow Developer downloaded!
#          Job 6: Data Technology Architect downloaded!
#          Job 7: Cloud Data Engineer downloaded!
#          Job 8: Data Architect downloaded!
#          Job 9: Data Technology Architect downloaded!
#          Job 10: ServiceNow Developer downloaded!
#          Job 11: ServiceNow Developer downloaded!
#          Job 12: Cloud Data Platform Engineer downloaded!
#          Job 13: Cloud Data Platform Engineer downloaded!
#          Job 14: CDP Architect downloaded!
#          Job 15: ServiceNow Consultant downloaded!
#          Job 16: Data Technology Architect downloaded!
#          Job 17: ServiceNow Developer downloaded!
#          Job 18: Cloud Data Engineer downloaded!
#          Job 19: Data Architect downloaded!
#          Job 20: Data Technology Architect downloaded!
#          Job 21: Cloud Data Engineer downloaded!
#          Job 22: Cloud Data Platform Engineer downloaded!
# Company 13: Wärtsilä
#          Job 1: Assistant, Research & Technology and Engineering downloaded!
# Company 14: F-Secure
#          No jobs found for F-Secure
# Company 15: Neste
#          No jobs found for Neste
# Company 16: Nordea
#          Job 1: Head of Data, in Financial Crime Intelligence, Investigations & Analytics (FCIIA) downloaded!
#          Job 2: Quantitative Risk Analyst - Credit Provisioning downloaded!
# Company 17: Aiven
#          No jobs found for Aiven
# Company 18: Unikie
#          Job 1: Full-Stack Developer in Abu Dhabi downloaded!
#          Job 2: Full-Stack Developer in Abu Dhabi downloaded!
#          Job 3: System Tester downloaded!
# Company 19: Smartly.io
#          Job 1: Backend Engineer (Feed Management) downloaded!
#          Job 2: Backend Engineer (Ad-lib Integrations) downloaded!
#          Job 3: Lead Engineer (User Experience) downloaded!
#          Job 4: Senior Backend Engineer (Ad-lib Integrations) downloaded!
#          Job 5: Payroll Coordinator downloaded!
#          Job 6: Backend Engineer (Feed Management) downloaded!
#          Job 7: Senior Fullstack Engineer (NodeJS/React) downloaded!
#          Job 8: Senior Backend Engineer (Ad-lib Integrations) downloaded!
#          Job 9: Backend Engineer (Feed Management) downloaded!
# Company 20: Nokia
#          Job 1: Talent Attraction Trainee downloaded!
#          Job 2: Senior Legal Counsel downloaded!
#          Job 3: Trainee, Espoo 5G Cloud Infra downloaded!
#          Job 4: IP Sales Engineer downloaded!
#          Job 5: Technical Specialist, SoC downloaded!
#          Job 6: Feature Owner Team Leader downloaded!
#          Job 7: Architect, SoC Architecture downloaded!
#          Job 8: Trainee, NMP Technical Support Specialist downloaded!
#          Job 9: CPO Digital Strategy Lead downloaded!
#          Job 10: Senior Legal Counsel downloaded!
#          Job 11: Trainee, Technical Communication downloaded!
#          Job 12: Trainee, Espoo 5G Cloud Infra downloaded!
#          Job 13: IP Sales Engineer downloaded!
#          Job 14: Technical Specialist, SoC downloaded!
#          Job 15: Trainee, Enterprise Campus Edge downloaded!
#          Job 16: Patent Engineer / Senior Patent Specialist downloaded!
#          Job 17: Trainee, Open Source Security downloaded!
#          Job 18: Feature Owner Team Leader downloaded!
#          Job 19: Architect, SoC Architecture downloaded!
#          Job 20: (Principal) Technical Architect downloaded!
#          Job 21: Golang Developer downloaded!
# Company 21: Vaisala
#          Job 1: Senior Test Engineer downloaded!
#          Job 2: Software Engineer, Weather Sensors downloaded!
#          Job 3: Senior Test Engineer downloaded!
#          Job 4: Software Engineer, Weather Sensors downloaded!
#          Job 5: Senior Test Engineer downloaded!
#          Job 6: Software Engineer, Weather Sensors downloaded!
#          Job 7: Senior Test Engineer downloaded!
# Company 22: Futurice
#          Job 1: Tech Lead / Architect downloaded!
#          Job 2: Senior Data Engineer downloaded!
#          Job 3: CRM Consultant - Helsinki downloaded!
#          Job 4: Marketing Automation Consultant - Tampere downloaded!
#          Job 5: CRM Consultant - Tampere downloaded!
#          Job 6: Senior Web Analytics Consultant - Helsinki downloaded!
#          Job
Senior Web Analytics Consultant - Tampere downloaded!
#          Job 214: Senior Software Developer - Tampere downloaded!
#          Job 215: Salesforce Developer - Helsinki downloaded!
#          Job 216: Salesforce Developer - Tampere downloaded!
#          Job 217: Tech Lead / Architect downloaded!
#          Job 218: Senior Data Engineer downloaded!
#          Job 219: CRM Consultant - Helsinki downloaded!
#          Job 220: Marketing Automation Consultant - Tampere downloaded!
#          Job 221: CRM Consultant - Tampere downloaded!
#          Job 222: Senior Web Analytics Consultant - Helsinki downloaded!
#          Job 223: Senior Software Developer - Helsinki downloaded!
#          Job 224: Senior Web Analytics Consultant - Tampere downloaded!
#          Job 225: Senior Software Developer - Tampere downloaded!
#          Job 226: Salesforce Developer - Helsinki downloaded!
#          Job 227: Salesforce Developer - Tampere downloaded!
#          Job 228: Tech Lead / Architect downloaded!
#          Job 229: Senior Data Engineer downloaded!
#          Job 230: CRM Consultant - Helsinki downloaded!
#          Job 231: Marketing Automation Consultant - Tampere downloaded!
#          Job 232: CRM Consultant - Tampere downloaded!
#          Job 233: Senior Web Analytics Consultant - Helsinki downloaded!
#          Job 234: Senior Software Developer - Helsinki downloaded!
#          Job 235: Senior Web Analytics Consultant - Tampere downloaded!
#          Job 236: Senior Software Developer - Tampere downloaded!
#          Job 237: Salesforce Developer - Helsinki downloaded!
#          Job 238: Salesforce Developer - Tampere downloaded!
#          Job 239: Tech Lead / Architect downloaded!
#          Job 240: Senior Data Engineer downloaded!
#          Job 241: CRM Consultant - Helsinki downloaded!
#          Job 242: Marketing Automation Consultant - Tampere downloaded!
#          Job 243: CRM Consultant - Tampere downloaded!
#          Job 244: CRM Consultant - Helsinki downloaded!
#          Job 245: Marketing Automation Consultant - Tampere downloaded!
#          Job 246: CRM Consultant - Tampere downloaded!
#          Job 247: Senior Web Analytics Consultant - Helsinki downloaded!
#          Job 248: Senior Software Developer - Helsinki downloaded!
#          Job 249: Senior Software Developer - Tampere downloaded!
#          Job 250: Salesforce Developer - Helsinki downloaded!
# Company 23: Elisa
#          No jobs found for Elisa
# Company 24: Taiste
#          Job 1: Frontend Developer downloaded!
#          Job 2: Frontend Developer downloaded!
#          Job 3: Frontend Developer downloaded!
#          Job 4: Back End Developer downloaded!
#          Job 5: Back End Developer downloaded!
#          Job 6: Frontend Developer downloaded!
# Company 25: AlphaSense
#          Job 1: Staff Lead Software Engineer - Enterprise / Cloud-Agnostic downloaded!
#          Job 2: Senior/Staff Search Engineer - Enterprise / Cloud-Agnostic downloaded!
#          Job 3: Senior Software Engineer - GraphQL API downloaded!
#          Job 4: Senior Search Engineer (Solr Platform) downloaded!
#          Job 5: Staff Lead Software Engineer - Enterprise / Cloud-Agnostic downloaded!
#          Job 6: Senior Search Engineer (Solr Platform) downloaded!
#          Job 7: Senior Full-stack Engineer downloaded!
# Company 26: Gofore
#          No jobs found for Gofore
# Company 27: Canonical
#          Job 1: Executive Assistant downloaded!
#          Job 2: Marketing operations specialist downloaded!
#          Job 3: Talent Analytics Lead downloaded!
#          Job 4: Chief Information Security Officer downloaded!
#          Job 5: Product Marketing Lead downloaded!
#          Job 6: Technical Author - Ubuntu and Canonical products downloaded!
# Company 28: Vincit
#          Job 1: Software Architect downloaded!
#          Job 2: Cloud Architect downloaded!
#          Job 3: Cloud Architect downloaded!
#
# Total 578 jobs downloaded!
